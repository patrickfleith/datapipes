# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickfleith/datapipes/blob/main/Simple_Question_Generation_Distilabel_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Easy Question Generation with distilabel and OpenAI
# In this notebook I show you how to use OpenAI in distilabel to generate a bunch of questions.

# %% [markdown]
# ## Install distilabel and OpenAI setup
# - Here is how to install distilabel within a Google Colab notebook
# - You need to configure the OpenAI key. If you have doubts, look at this notebook [here](https://github.com/patrickfleith/datapipes/blob/main/How_to_use_an_OpenAI_Chat_model.ipynb)

# %%
# !pip install distilabel --upgrade --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.2/442.2 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import openai, distilabel
from distilabel.llms import OpenAILLM
from google.colab import userdata
from itertools import product

# %%
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
# printing my version such you can check yours
print(f"Open AI version: {openai.__version__}")
print(f"Distilabel version: {distilabel.__version__}")
# Out:
# Open AI version: 1.54.3
# Distilabel version: 1.4.1

# %% [markdown]
# ## Configuration
# For this demo notebook we want to generate **questions of several difficulty levels for given topics**
#
# So we let you define some
# - difficulty levels: no more than 4 is recommended.
# - topics: you could be more specific and have a much longer list than the one below
#
# 💡 I created my list using an LLM. You see how it starts to be interesting?

# %%
# config
levels = ["easy", "typical", "difficult", "hardcore"]

topics = [
    # Classical Mechanics
    "Newton's Laws of Motion",
    "Kinematics and Dynamics",
    "Work, Energy, and Power",
    "Momentum and Collisions",
    "Rotational Motion and Angular Momentum",
    "Gravitation and Orbital Mechanics",
    "Fluid Mechanics",
    "Harmonic Motion and Oscillations",
    "Lagrangian and Hamiltonian Mechanics",

    # Thermodynamics and Statistical Mechanics
    "Temperature and Heat",
    "Laws of Thermodynamics",
    "Entropy and the Second Law",
    "Thermodynamic Processes",
    "Heat Engines and Refrigerators",
    "Statistical Mechanics and Probability",
    "Kinetic Theory of Gases",
    "Phase Transitions and Critical Phenomena",

    # Electromagnetism
    "Electrostatics (Coulomb’s Law, Electric Fields, Potential)",
    "Electric Circuits (Ohm’s Law, Kirchhoff’s Laws, AC/DC Circuits)",
    "Magnetostatics (Magnetic Fields, Biot-Savart Law, Ampère's Law)",
    "Electromagnetic Induction (Faraday's Law, Lenz’s Law)",
    "Maxwell's Equations",
    "Electromagnetic Waves and Light",
    "Optics (Geometric and Wave Optics)",

    # Quantum Mechanics
    "Wave-Particle Duality",
    "Schrödinger Equation",
    "Quantum States and Operators",
    "Quantum Harmonic Oscillator",
    "Angular Momentum and Spin",
    "Quantum Tunneling",
    "Heisenberg Uncertainty Principle",
    "Quantum Entanglement",
    "Atomic and Molecular Physics",

    # Relativity
    "Special Relativity (Time Dilation, Length Contraction, E=mc²)",
    "General Relativity (Gravitational Waves, Black Holes, Space-Time Curvature)",
    "Lorentz Transformations",
    "Relativistic Dynamics",

    # Nuclear and Particle Physics
    "Radioactivity and Nuclear Decay",
    "Nuclear Reactions and Fusion",
    "Particle Accelerators and Detectors",
    "Fundamental Particles (Quarks, Leptons, Bosons)",
    "The Standard Model of Particle Physics",
    "Quantum Chromodynamics (QCD)",
    "Symmetry and Conservation Laws",

    # Condensed Matter Physics
    "Crystallography and Lattice Structures",
    "Band Theory of Solids",
    "Semiconductors and Electronics",
    "Superconductivity",
    "Magnetism and Magnetic Materials",
    "Phase Transitions (Ferromagnetic, Antiferromagnetic, etc.)",
    "Nanomaterials and Nanotechnology",

    # Astrophysics and Cosmology
    "The Structure of Stars and Stellar Evolution",
    "Galaxies and Dark Matter",
    "Big Bang Theory and Cosmic Microwave Background",
    "Expansion of the Universe and Dark Energy",
    "Black Holes and Neutron Stars",
    "Exoplanets and Habitability",
    "Gravitational Lensing",

    # Plasma Physics
    "Basics of Plasma States",
    "Plasma Confinement and Fusion Energy",
    "Magnetohydrodynamics (MHD)",
    "Space and Astrophysical Plasmas",
    "Plasma Applications (Lasers, Propulsion)",

    # Mathematical Physics
    "Vector Calculus and Differential Equations",
    "Tensor Analysis and General Relativity",
    "Group Theory and Symmetry",
    "Complex Analysis and Fourier Transforms",
    "Computational Physics and Numerical Methods",

    # Modern and Applied Physics
    "Solid-State Physics",
    "Quantum Computing and Information Theory",
    "Materials Science",
    "Biophysics and Medical Physics",
    "Optoelectronics and Photonics",
    "Renewable Energy Technologies"
]

# %%
print(f"A total of {len(levels)*len(topics)} questions will be generated")
# Out:
# A total of 296 questions will be generated

# %% [markdown]
# # TCMMI framework
# - Templates
# - Constructor
# - Messages
# - Model
# - Inference

# %%
# prompt template
prompt_template = "Ask me a {level} question about {topic}. Only respond with the question, nothing else."

# prompt constructor
prompts = [prompt_template.format(level=level, topic=topic) for level, topic in product(levels, topics)]

# messages assembly
inputs = [[{"role": "user", "content": prompt}] for prompt in prompts]

# llm
llm = OpenAILLM(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
llm.load()

# inference
outputs = llm.generate_outputs(inputs=inputs, temperature=0.9)
outputs
# Out:
# [["What is Newton's first law of motion commonly known as?"],
#  ['What is the formula for calculating the average velocity of an object?'],
#  ['What is the formula for calculating work done when a force is applied over a distance?'],
#  ['What is the law of conservation of momentum?'],
#  ['What is the formula for calculating the angular momentum of an object rotating about an axis?'],
#  ['What force keeps planets in orbit around the Sun?'],
#  ['What is the main difference between a liquid and a gas in terms of their ability to flow?'],
#  ['What is the term used to describe the time it takes for one complete cycle of oscillation in harmonic motion?'],
#  ['What is the principle of least action in the context of Lagrangian mechanics?'],
#  ['What is the difference between temperature and heat?'],
#  ['What is the first law of thermodynamics commonly known as?'],
#  ['What does the Second Law of Thermodynamics state about the direction of natural processes in terms of entropy?'],
#  ['What is the process called where a gas expands and does work on its surroundings without exchanging heat with its environment?'],
#  ['What is the primary purpose of a heat engine?'],
#  ['What is the definition of a microstate in the context of statistical mechanics?'],
#  ['What is the main assumption of the kinetic theory of gases regarding the motion of gas particles?'],
#  ['What is a phase transition?'],
#  ["What is the relationship between the electric force and the distance between two point charges according to Coulomb's Law?"],
#  ["What is the formula for calculating resistance using Ohm's Law?"],
#  ['What is the direction of the magnetic field around a straight current-carrying wire?'],
#  ["What is Faraday's Law of Electromagnetic Induction?"],
#  ["What are the four equations that make up Maxwell's Equations?"],
#  ['What is the speed of light in a vacuum?'],
#  ['What is the law that describes the relationship between the angles of incidence and refraction when light passes from one medium to another?'],
#  ['What is wave-particle duality?'],
#  ['What does the Schrödinger Equation describe in quantum mechanics?'],
#  ['What is a quantum state typically represented by in quantum mechanics?'],
#  ['What is the ground state energy of a quantum harmonic oscillator?'],
#  ['What is the relationship between angular momentum and spin in quantum mechanics?'],
#  ['What is quantum tunneling?'],
#  ['What does the Heisenberg Uncertainty Principle state about the relationship between position and momentum?'],
#  ['What is quantum entanglement?'],
#  ['What is the smallest unit of an element that retains its chemical properties?'],
#  ['What happens to time for a moving observer compared to a stationary observer according to the concept of time dilation in special relativity?'],
#  ['What is the name of the phenomenon predicted by General Relativity that occurs when massive objects like black holes accelerate and cause ripples in space-time?'],
#  ['What is the main purpose of Lorentz transformations in physics?'],
#  ['What is the equation that relates energy, mass, and momentum in relativistic dynamics?'],
#  ['What is the term used to describe the process by which an unstable atomic nucleus loses energy by emitting radiation?'],
#  ['What is the primary process that powers the sun and other stars?'],
#  ['What is the primary purpose of a particle accelerator?'],
#  ['What are the three types of quarks?'],
#  ['What are the two main categories of particles in the Standard Model of Particle Physics?'],
#  ['What is the fundamental force that Quantum Chromodynamics (QCD) describes?'],
#  ['What is the principle of conservation of momentum?'],
#  ['What is the basic repeating unit of a crystal lattice called?'],
#  ['What are the two main types of bands in the Band Theory of Solids?'],
#  ['What is the basic function of a diode in an electronic circuit?'],
#  ['What is superconductivity?'],
#  ['What is the unit of measurement for magnetic field strength?'],
#  ['What is a phase transition in the context of magnetism?'],
#  ['What are nanomaterials typically defined as in terms of size?'],
#  ['What is the main source of energy in stars during their main sequence phase?'],
#  ["What is the term for the invisible substance that is believed to make up a large portion of the universe's mass and is thought to influence the gravitational behavior of galaxies?"],
#  ['What is the Cosmic Microwave Background radiation often considered to be a relic of?'],
#  ['What is the term used to describe the force that is believed to be causing the accelerated expansion of the Universe?'],
#  ['What is a black hole?'],
#  ['What is the "habitable zone" around a star?'],
#  ['What is gravitational lensing?'],
#  ['What is plasma often referred to as, in terms of its state of matter?'],
#  ['What is the primary goal of plasma confinement in fusion energy research?'],
#  ['What does the term "magnetohydrodynamics" refer to?'],
#  ['What is the name of the force that keeps the planets in orbit around the Sun?'],
#  ['What is one common application of plasma in laser technology?'],
#  ['What is the gradient of a scalar function \\( f(x, y, z) = x^2 + y^2 + z^2 \\)?'],
#  ['What is a tensor?'],
#  ['What is the definition of a group in the context of group theory?'],
#  ['What is the value of the integral of the function \\( e^{ix} \\) over one complete period from \\( 0 \\) to \\( 2\\pi \\)?'],
#  ['What is the purpose of numerical methods in computational physics?'],
#  ['What is the difference between a conductor, an insulator, and a semiconductor?'],
#  ['What is a qubit?'],
#  ['What is the primary building block of metals?'],
#  ['What is the basic unit of energy commonly used in biophysics to describe the energy of biomolecules?'],
#  ['What is the primary function of a light-emitting diode (LED) in optoelectronics?'],
#  ['What is the main source of energy for solar power?'],
#  ["What are Newton's three laws of motion, and can you provide an example for each?"],
#  ['What is the relationship between displacement, velocity, and acceleration in one-dimensional motion?'],
#  ['What is the relationship between work, energy, and power in a mechanical system?'],
#  ['A 2 kg object moving at a velocity of 3 m/s collides elastically with a stationary 1 kg object. What are the final velocities of both objects after the collision?'],
#  ['What is the relationship between torque, angular acceleration, and the moment of inertia in rotational motion?'],
#  ["What is the relationship between the gravitational force between two masses and the distance separating them, according to Newton's law of universal gravitation?"],
#  ["What is the Bernoulli's equation and how is it applied in fluid flow analysis?"],
#  ['What is the difference between simple harmonic motion and damped harmonic motion?'],
#  ['What is the principle of least action, and how does it relate to the Lagrangian formulation of mechanics?'],
#  ['What is the difference between temperature and heat?'],
#  ['What is the first law of thermodynamics and how does it apply to energy conservation in a closed system?'],
#  ['What does the Second Law of Thermodynamics state about the direction of spontaneous processes in isolated systems?'],
#  ['What are the differences between isothermal, adiabatic, isobaric, and isochoric processes in thermodynamics?'],
#  ['What is the difference between the coefficient of performance (COP) of a refrigerator and the efficiency of a heat engine?'],
#  ['What is the significance of the partition function in statistical mechanics?'],
#  ['What are the main assumptions of the kinetic theory of gases?'],
#  ['What is the significance of the critical temperature in phase transitions, and how does it relate to the concept of critical phenomena?'],
#  ['What is the electric field strength due to a point charge of +5 µC located at a distance of 2 meters from the charge?'],
#  ["What is the relationship between voltage, current, and resistance in Ohm's Law?"],
#  ['What is the magnetic field at a point in space due to a long straight current-carrying wire using the Biot-Savart Law?'],
#  ["What is Faraday's Law of Electromagnetic Induction and how does it relate to Lenz's Law?"],
#  ["What do Maxwell's Equations describe in the context of electromagnetism?"],
#  ['What is the relationship between the frequency and wavelength of electromagnetic waves?'],
#  ["What is the relationship between the angle of incidence and the angle of refraction in Snell's Law?"],
#  ['What is wave-particle duality and how does it apply to photons and electrons?'],
#  ['What is the significance of the Schrödinger equation in quantum mechanics?'],
#  ['What is the significance of the commutation relation between two operators in quantum mechanics, and how does it relate to the uncertainty principle?'],
#  ['What is the significance of the zero-point energy in the quantum harmonic oscillator?'],
#  ['What is the difference between orbital angular momentum and spin angular momentum in quantum mechanics?'],
#  ['What is quantum tunneling and how does it occur at the subatomic level?'],
#  ['What does the Heisenberg Uncertainty Principle signify about the simultaneous measurement of position and momentum of a particle?'],
#  ['What is quantum entanglement and how does it challenge classical notions of locality?'],
#  ['What is the significance of the Heisenberg uncertainty principle in the context of atomic and molecular physics?'],
#  ['How does time dilation affect the aging of astronauts traveling at relativistic speeds compared to people on Earth?'],
#  ['How do gravitational waves affect the fabric of space-time as they propagate through it?'],
#  ['What is the mathematical expression for the Lorentz transformation for time and space coordinates between two reference frames moving at a constant velocity relative to each other?'],
#  ['How does the concept of relativistic momentum differ from classical momentum, and what implications does this have for objects moving close to the speed of light?'],
#  ['What is the difference between alpha decay, beta decay, and gamma decay in terms of particle emission and changes in the atomic nucleus?'],
#  ['What are the key conditions required for nuclear fusion to occur in stars?'],
#  ['What are the main types of particle accelerators, and how do they differ in their operating principles?'],
#  ['What are the six types (flavors) of quarks, and how do they differ from leptons in terms of their properties?'],
#  ['What are the six types of quarks in the Standard Model of Particle Physics?'],
#  ['What is the significance of confinement in Quantum Chromodynamics?'],
#  ["How does Noether's theorem relate symmetries to conservation laws in physics?"],
#  ['What is the difference between a simple cubic lattice and a body-centered cubic lattice in terms of coordination number and atomic packing efficiency?'],
#  ['What is the difference between conduction bands and valence bands in solid materials?'],
#  ['What are the main differences between n-type and p-type semiconductors?'],
#  ['What are the key characteristics that define a material as a superconductor?'],
#  ['What is the difference between ferromagnetic, paramagnetic, and diamagnetic materials?'],
#  ['What is the role of temperature in the phase transition from a ferromagnetic to a paramagnetic state?'],
#  ['What are the key properties that make nanomaterials unique compared to their bulk counterparts?'],
#  ['What are the main stages of stellar evolution for a sun-like star?'],
#  ['What evidence supports the existence of dark matter in galaxies?'],
#  ['What is the significance of the Cosmic Microwave Background radiation in the context of the Big Bang Theory?'],
#  ['What role does dark energy play in the accelerated expansion of the universe?'],
#  ['What are the key differences between black holes and neutron stars in terms of their formation and properties?'],
#  ['What factors make a planet potentially habitable in terms of its distance from its star?'],
#  ['What is gravitational lensing and how does it occur in the context of general relativity?'],
#  ['What are the key characteristics that distinguish plasma from the other three states of matter: solid, liquid, and gas?'],
#  ['What are the main methods of plasma confinement used in fusion reactors?'],
#  ['What are the fundamental equations governing magnetohydrodynamics, and how do they combine the principles of fluid dynamics and electromagnetism?'],
#  ['What role do magnetic fields play in the behavior of astrophysical plasmas?'],
#  ['What are the key advantages of using plasma propulsion systems compared to traditional chemical propulsion in spacecraft?'],
#  ['What is the divergence of a vector field, and how is it physically interpreted in the context of fluid flow?'],
#  ['What is the significance of the Riemann curvature tensor in the context of General Relativity, and how does it relate to the concept of spacetime curvature?'],
#  ['What is the significance of the group of symmetries of a geometric object in relation to its invariance under transformations?'],
#  ['What is the relationship between the residue theorem in complex analysis and the computation of Fourier transforms of functions?'],
#  ['What is the difference between explicit and implicit methods in numerical integration, and in which scenarios might you prefer one over the other?'],
#  ['What is the significance of the band gap in determining the electrical conductivity of semiconductor materials?'],
#  ['What is the significance of qubits in quantum computing compared to classical bits in traditional computing?'],
#  ['What is the difference between ductility and malleability in materials?'],
#  ['What role do biophysics and medical physics play in the development of imaging techniques such as MRI and CT scans?'],
#  ['What are the key differences between optoelectronics and photonics in terms of their applications and principles?'],
#  ['What are the advantages and disadvantages of using solar panels for electricity generation?'],
#  ["How do Newton's Laws of Motion apply to the motion of a satellite in orbit around the Earth, and what role does gravitational force play in that context?"],
#  ["A 1,500 kg car accelerates uniformly from rest to a speed of 25 m/s over a distance of 200 meters. Calculate the total work done on the car during this acceleration, and determine the average power output of the car's engine during this time if the acceleration occurs over a period of 10 seconds."],
#  ['A 10 kg box is pushed across a frictionless surface with a constant horizontal force of 50 N. If the box is initially at rest, how much work is done on the box after it has moved 5 meters? Additionally, calculate the power expended if this distance is covered in 2 seconds.'],
#  ['A 2 kg cart moving at 3 m/s collides elastically with a stationary 1 kg cart. What are the final velocities of both carts after the collision?'],
#  ["A solid disk of mass M and radius R is rotating about its central axis with an angular speed ω. If the disk is then uniformly heated, causing its radius to expand to a new radius R', while maintaining the same mass, how does the angular momentum of the disk change as a function of the new radius, and what assumptions must be made regarding the temperature and material properties of the disk?"],
#  ['What is the significance of the three-body problem in celestial mechanics, and how does it differ from the two-body problem in terms of the predictability of the motion of the bodies involved?'],
#  ['Explain the significance of the Reynolds number in predicting flow regimes and how it influences the transition between laminar and turbulent flow in a pipe.'],
#  ['In a damped harmonic oscillator, how does the energy of the system change over time, and what factors influence the rate of energy dissipation?'],
#  ['How do the principles of least action and symplectic geometry relate to each other in the context of Hamiltonian mechanics, and what implications does this relationship have for the conservation of certain physical quantities?'],
#  ['How does the specific heat capacity of a substance influence its temperature change during the absorption or release of heat, and how can this principle be applied to calculate the final temperature of a mixture of different substances?'],
#  ['How do the concepts of entropy and enthalpy clarify the distinction between reversible and irreversible processes in the context of the second law of thermodynamics?'],
#  ['How does the concept of entropy in statistical mechanics reconcile with macroscopic observations of the Second Law of Thermodynamics, particularly in systems exhibiting non-equilibrium behavior?'],
#  ['Explain the differences in the thermodynamic processes of isothermal, adiabatic, isochoric, and isobaric transformations, and how each process affects the internal energy and enthalpy of an ideal gas.'],
#  ['What is the relationship between the Coefficient of Performance (COP) of a refrigerator and the efficiency of a heat engine operating between the same two temperature reservoirs, and how does this relationship illustrate the second law of thermodynamics?'],
#  ['What is the significance of the partition function in statistical mechanics, and how does it relate to the macroscopic thermodynamic properties of a system in equilibrium?'],
#  ['How does the Maxwell-Boltzmann distribution describe the velocity distribution of gas molecules at different temperatures, and what are the implications of this distribution on the mean free path of gas particles?'],
#  ['How does the concept of universality relate to critical exponents in phase transitions, and what role do dimensionality and symmetry play in determining these critical exponents?'],
#  ['A uniformly charged sphere of radius R has a total charge Q distributed uniformly over its surface. Calculate the electric field at a point located a distance d from the center of the sphere, where d > R, and determine the electric potential at that point.'],
#  ["In a circuit with two resistors in series (R1 = 4Ω and R2 = 6Ω) connected to a 20V DC power supply, calculate the voltage drop across each resistor and the total current flowing through the circuit using Ohm’s Law and Kirchhoff's Voltage Law."],
#  ["Consider a long, straight conductor carrying a steady current \\( I \\). At a distance \\( r \\) from the conductor, derive the expression for the magnetic field \\( B \\) using both the Biot-Savart Law and Ampère's Law. Discuss the conditions under which your derivation using each law is valid and any assumptions made in the process."],
#  ['How does the direction of the induced electromotive force (emf) in a coil change when the magnetic field passing through it is increased at a constant rate, and how can Lenz’s Law be applied to explain this phenomenon?'],
#  ["How do Maxwell's Equations indicate the existence of electromagnetic waves, and what is the significance of the wave equation derived from them?"],
#  ['Explain the significance of the Poynting vector in the context of electromagnetic wave propagation, and how it relates to the energy flow of electromagnetic radiation in free space.'],
#  ['Consider a thin lens with a focal length of 20 cm. An object is placed 10 cm from the lens. Calculate the position and nature (real or virtual) of the image formed by the lens, and explain how the lens formula and magnification equation are applied in this scenario.'],
#  ['How does the phenomenon of wave-particle duality challenge classical mechanics, and what implications does it have for our understanding of the nature of reality in quantum physics?'],
#  ['How does the inclusion of a potential energy function in the time-independent Schrödinger equation affect the behavior of a quantum particle in a one-dimensional infinite potential well compared to a finite potential well?'],
#  ['How does the representation of quantum states change when transitioning from the position basis to the momentum basis, and what implications does this have for the uncertainty principle?'],
#  ['What is the significance of the zero-point energy in the quantum harmonic oscillator, and how does it lead to the phenomenon of zero-point fluctuations?'],
#  ['How does the concept of spin in quantum mechanics relate to the conservation of angular momentum in systems with both intrinsic and orbital angular momentum, and what implications does this have for understanding particle statistics in fermions versus bosons?'],
#  ['How does quantum tunneling challenge classical notions of particle behavior, and what implications does this have for technologies such as quantum computing and scanning tunneling microscopy?'],
#  ['How does the Heisenberg Uncertainty Principle fundamentally challenge the classical notion of determinism in physics, and what implications does this have for our understanding of measurement and observation in quantum mechanics?'],
#  ['What are the implications of quantum entanglement for the concept of locality and the principle of separability in quantum mechanics?'],
#  ['What are the implications of quantum entanglement for the concept of locality in quantum mechanics, and how does this challenge classical intuitions about separability and causation?'],
#  ['How does the concept of simultaneity differ between observers moving at relativistic speeds, and how does this affect the calculation of time dilation for two events that are simultaneous in one frame but not in another?'],
#  ['How does the emission of gravitational waves from a binary black hole merger affect the curvature of spacetime, and what implications does this have for the observation of those waves by detectors like LIGO and Virgo?'],
#  ['How do Lorentz transformations affect the simultaneity of events observed in different inertial frames, and what implications does this have for the concept of absolute time in the context of special relativity?'],
#  ['How does the concept of relativistic mass affect the formulation of momentum in a relativistic framework, and what implications does this have for the conservation of momentum in collisions involving fast-moving particles?'],
#  ['What factors determine the half-life of a radioactive isotope, and how do these factors influence the stability and decay modes of the isotope?'],
#  ['What are the primary challenges associated with achieving and maintaining the conditions necessary for sustained nuclear fusion, and how do these challenges differ from those encountered in nuclear fission?'],
#  ['What are the primary challenges and limitations associated with achieving and maintaining the extremely high vacuum required in particle accelerators, particularly in the context of beam stability and particle collision rates?'],
#  ['What is the significance of the Higgs boson in the Standard Model of particle physics, and how does it relate to the mechanism of mass generation for fundamental particles?'],
#  ['What is the significance of the Higgs boson in the context of electroweak symmetry breaking, and how does its mechanism relate to the masses of other fundamental particles in the Standard Model?'],
#  ['What are the implications of confinement in Quantum Chromodynamics for the nature of hadrons, and how does this phenomenon challenge the concept of asymptotic freedom?'],
#  ["How does Noether's theorem relate the symmetries of a physical system to its conservation laws, and can you provide an example illustrating this relationship in a specific physical context?"],
#  ['What is the significance of the Laue conditions in determining the symmetry of a crystal lattice, and how do they relate to the Miller indices of crystallographic planes?'],
#  ['How does the concept of effective mass in band theory relate to the mobility of charge carriers in semiconductors, and what implications does this have for the design of electronic devices?'],
#  ["What are the implications of quantum tunneling on the performance and scaling of advanced semiconductor devices, particularly in relation to Moore's Law?"],
#  ['What are the key differences between conventional superconductors and high-temperature superconductors in terms of their pairing mechanisms and critical temperature characteristics?'],
#  ['What is the difference between ferromagnetism, paramagnetism, and diamagnetism in terms of their magnetic susceptibility and the behavior of materials in an external magnetic field?'],
#  ['What is the significance of the order parameter in distinguishing between first-order and second-order phase transitions in ferromagnetic and antiferromagnetic materials, and how does it relate to symmetry breaking?'],
#  ['What are the potential environmental and health risks associated with the synthesis and disposal of nanomaterials, and how can they be mitigated through regulatory measures?'],
#  ['What are the key differences in nucleosynthesis processes between low-mass stars and high-mass stars during their respective life cycles, and how do these differences impact the eventual fate of each type of star?'],
#  ['How does the presence of dark matter influence the rotation curves of spiral galaxies, and what implications does this have for our understanding of galaxy formation and evolution?'],
#  ['How does the anisotropy in the Cosmic Microwave Background radiation provide evidence for the inflationary model of the early universe, and what specific measurements from the WMAP and Planck satellites support this hypothesis?'],
#  ['What are the implications of the differing measurements of the Hubble constant on our understanding of dark energy and the expansion of the universe?'],
#  ['What is the role of the equation of state in determining the stability and formation of neutron stars, and how does it influence the transition between a neutron star and a black hole during gravitational collapse?'],
#  ['What are the potential geological and atmospheric conditions on an exoplanet that could allow for the existence of liquid water, and how do these factors influence its overall habitability?'],
#  ['How does the phenomenon of gravitational lensing provide evidence for the existence of dark matter in galaxy clusters?'],
#  ['What are the key differences in the behavior of particles in a plasma state compared to those in a gas state, particularly in terms of ionization and conductivity?'],
#  ['What are the primary challenges associated with achieving and maintaining the necessary plasma confinement for sustained nuclear fusion reactions in a tokamak, and how do they differ from those faced in inertial confinement fusion experiments?'],
#  ['How does the inclusion of Hall effects influence the stability of magnetohydrodynamic waves in a partially ionized plasma?'],
#  ['What mechanisms are responsible for the acceleration of cosmic rays, and how do they relate to the properties of astrophysical plasmas in supernova remnants?'],
#  ['What are the primary challenges and limitations of achieving efficient energy transfer in plasma-based propulsion systems, such as those utilizing magnetoplasmadynamic or pulsed plasma thrusters?'],
#  ["Consider a three-dimensional vector field \\( \\mathbf{F}(x, y, z) = (y^2, xz, xy) \\). Using Stokes' theorem, compute the circulation of \\( \\mathbf{F} \\) along the curve \\( C \\) defined by the intersection of the plane \\( z = 1 \\) with the cylinder \\( x^2 + y^2 = 4 \\). What is the surface \\( S \\) over which you would apply the theorem, and how does the orientation of \\( S \\) affect your result?"],
#  ['How does the Riemann curvature tensor relate to the geodesic deviation equation, and what physical significance does the geodesic deviation have in the context of General Relativity?'],
#  ['What is the significance of the Sylow theorems in the classification of finite groups, and how do they relate to the concept of group actions on sets?'],
#  ['Let \\( f(z) \\) be an analytic function in the upper half-plane for which \\( f(z) \\to 0 \\) as \\( \\text{Im}(z) \\to \\infty \\). If \\( f(z) \\) is expressed in terms of its Fourier transform, what is the relationship between \\( f(z) \\) and its boundary values on the real line? Specifically, derive the formula that connects \\( f(z) \\) to its Fourier transform \\( \\hat{f}(\\xi) \\) given the condition \\( f(z) = \\int_{-\\infty}^{\\infty} \\'],
#  ['How can the convergence and stability of numerical solutions to partial differential equations be analyzed, and what role do discretization methods such as finite difference, finite element, and spectral methods play in this analysis?'],
#  ['What are the implications of Berry curvature in the context of the quantum Hall effect, and how does it relate to the geometric phase in solid-state systems?'],
#  ['How does the phenomenon of quantum entanglement challenge classical notions of information locality, and what implications does this have for the security of quantum key distribution protocols?'],
#  ['How does the dislocation theory explain the mechanisms of plastic deformation in crystalline solids, and what role does the Frank-Read mechanism play in this process?'],
#  ['How do the principles of quantum mechanics apply to the mechanisms of electron transfer in photosynthesis, and what implications does this have for the efficiency of energy conversion in biological systems?'],
#  ['What are the primary differences in performance and application between quantum dot lasers and traditional semiconductor lasers?'],
#  ['What are the key challenges and potential solutions associated with the integration of intermittent renewable energy sources, such as solar and wind, into existing power grid infrastructure?'],
#  ["How would you apply Newton's second law of motion to calculate the net force acting on a car that is accelerating at 3 m/s², given that its mass is 1,200 kg, and explain how this net force changes if the car encounters a frictional force of 500 N opposing its motion?"],
#  ['A particle moves along a straight line with a position function given by \\( s(t) = 3t^3 - 12t^2 + 9t + 5 \\) for \\( t \\geq 0 \\). Determine the time(s) at which the particle changes direction and find the corresponding positions.'],
#  ['A 1000 kg car is moving at a speed of 20 m/s when the driver suddenly applies the brakes, causing the car to decelerate at a constant rate of 5 m/s² until it comes to a complete stop. Calculate the total work done by the brakes during this process and the time taken for the car to stop.'],
#  ['A 1500 kg car traveling at 20 m/s collides head-on with a 1000 kg motorcycle traveling at 15 m/s in the opposite direction. Assuming a perfectly inelastic collision, calculate the final velocity of the combined mass immediately after the collision.'],
#  ['A solid disk of mass \\( m \\) and radius \\( r \\) rolls without slipping on a horizontal surface. If it has an initial angular velocity \\( \\omega_0 \\) and then collides elastically with a stationary solid sphere of mass \\( M \\) and radius \\( R \\), what will be the final angular velocity of the disk and the final velocity of the center of mass of the sphere after the collision? Assume both objects are rigid and that the collision occurs at the edge of the disk.'],
#  ["Given a two-body system where one body is a large planet and the other is a small satellite, derive the equations of motion for the satellite in the frame of reference of the planet, assuming the planet's gravitational field is spherically symmetric and that the satellite's mass is negligible compared to the planet's mass. Analyze the stability of circular orbits and determine the conditions under which these orbits can be classified as stable or unstable."],
#  ['What are the implications of the Navier-Stokes existence and smoothness problem on the predictability of fluid flow in turbulent regimes?'],
#  ['In a damped harmonic oscillator, if the damping force is proportional to the velocity, derive the equation of motion and determine the conditions under which the system exhibits underdamped, critically damped, and overdamped behavior.'],
#  ['How do you derive the equations of motion for a non-conservative system using the Lagrangian formalism, and how do these equations compare to those obtained using Hamiltonian mechanics?'],
#  ['What is the relationship between the specific heat capacity of a substance and its temperature change when a known amount of heat is added or removed, and how does this principle apply in calculating the final temperature of a mixture of two substances at different temperatures?'],
#  ['Explain the implications of the Second Law of Thermodynamics on the concept of entropy in closed systems, and discuss its relevance to the arrow of time.'],
#  ['In a closed system, if the entropy of a particular subsystem decreases due to an irreversible process, can you explain how this local decrease can still comply with the Second Law of Thermodynamics, considering the total entropy of the entire system must still increase or remain constant?'],
#  ['Explain the implications of the Second Law of Thermodynamics in a closed system undergoing an irreversible process, and how it affects the entropy changes associated with the system and its surroundings.'],
#  ['Explain the relationship between the efficiency of a heat engine and the coefficients of performance for a refrigeration cycle operating between the same thermal reservoirs, and derive any relevant equations.'],
#  ['Consider a system of N non-interacting particles in a one-dimensional box of length L. If the particles are indistinguishable and obey Bose-Einstein statistics, derive the expression for the average occupation number of a single-particle energy state ε_i at thermal equilibrium and discuss how it differs from the classical Maxwell-Boltzmann distribution.'],
#  ['How does the distribution of molecular speeds in an ideal gas change with temperature, and what is the mathematical form of this distribution as described by the Maxwell-Boltzmann distribution?'],
#  ['Discuss the significance of the renormalization group approach in understanding the universality classes of phase transitions, and how it relates to the concept of critical exponents.'],
#  ['A charge of +3 µC is located at the origin, and a charge of -5 µC is located at (4 m, 0 m). Calculate the electric field at the point (2 m, 0 m) and determine the potential at that point due to both charges.'],
#  ["In a complex AC circuit consisting of multiple resistors, capacitors, and inductors, how would you apply Kirchhoff's Voltage Law (KVL) to analyze the circuit, and what role do phasors play in this analysis?"],
#  ["Consider a long, straight wire carrying a steady current \\( I \\). Calculate the magnetic field strength at a point located a distance \\( r \\) from the wire using both the Biot-Savart Law and Ampère's Law, and demonstrate that they yield the same result. What are the key assumptions made in each approach?"],
#  ['A circular loop of radius 0.1 m is placed in a uniform magnetic field of 0.5 T that is perpendicular to the plane of the loop. If the magnetic field is reduced to zero in 2 seconds, calculate the induced emf in the loop and determine the direction of the induced current using Lenz’s Law.'],
#  ["How can you derive the energy density of the electromagnetic field from Maxwell's equations, and what physical significance does this energy density have in the context of electromagnetic waves in a vacuum?"],
#  ['What is the relationship between the frequency, wavelength, and energy of a photon in the context of electromagnetic radiation, and how do these properties change as you move across the electromagnetic spectrum?'],
#  ['In a double-slit experiment, a monochromatic light source produces an interference pattern on a screen located at a distance L from the slits. If the distance between the slits is d and the wavelength of the light is λ, derive the expression for the position of the m-th order bright fringe on the screen, and discuss how this position changes as d is varied while keeping λ and L constant.'],
#  ['How does the concept of wave-particle duality challenge the classical distinction between particles and waves, and what implications does this have for our understanding of quantum mechanics?'],
#  ['In the context of the time-independent Schrödinger equation, derive the conditions under which a particle in a one-dimensional potential well exhibits quantized energy levels, and explain the physical significance of the boundary conditions applied.'],
#  ['Consider a quantum system described by a state vector \\( |\\psi\\rangle \\) in a two-dimensional Hilbert space. If the state vector can be expressed as \\( |\\psi\\rangle = a|0\\rangle + b|1\\rangle \\), where \\( |0\\rangle \\) and \\( |1\\rangle \\) are orthonormal basis states, derive the conditions on the coefficients \\( a \\) and \\( b \\) such that the state \\( |\\psi\\rangle \\) is normalized. Furthermore, if an observable \\( \\hat{A} \\) is represented by the operator \\( \\hat{A} ='],
#  ['What is the significance of the zero-point energy in the quantum harmonic oscillator, and how does it relate to the Heisenberg uncertainty principle?'],
#  ['How does the concept of spin in quantum mechanics challenge our classical understanding of angular momentum, particularly in the context of adding angular momentum vectors?'],
#  ["How does quantum tunneling challenge classical intuitions about potential barriers and particle behavior, particularly in the context of the Schrödinger equation and its implications for the probability distribution of a particle's position?"],
#  ['How does the Heisenberg Uncertainty Principle challenge the classical notion of determinism in quantum mechanics, and what implications does this have for the concept of particles having well-defined trajectories?'],
#  ['How does the phenomenon of quantum entanglement challenge classical notions of locality and causality, and what implications does this have for our understanding of the nature of reality?'],
#  ['What is the significance of the fine structure constant, α, in atomic physics, and how does it emerge from the combination of electromagnetic interaction and quantum mechanics?'],
#  ['If a spaceship travels at 0.8c (80% the speed of light) relative to an observer on Earth, how much time would pass on the spaceship for every 10 years that pass for the observer on Earth? Use the time dilation formula to calculate your answer.'],
#  ['How does the emission of gravitational waves from a binary black hole merger affect the curvature of spacetime in the vicinity of the event, and what implications does this have for the propagation of light in that region?'],
#  ['Derive the Lorentz transformation equations for time and space, and demonstrate how they ensure the constancy of the speed of light for all observers in inertial frames.'],
#  ['Consider a particle moving at a velocity close to the speed of light. Derive the equation for its relativistic momentum and explain how it differs from the classical momentum in the context of energy conservation during a high-energy collision.'],
#  ['What are the differences in decay mechanisms and half-lives between alpha, beta, and gamma radiation, and how do these differences affect the biological implications of exposure to each type of radiation?'],
#  ['What are the key differences in energy release and reaction conditions between deuterium-tritium fusion and proton-proton chain reactions in stellar environments?'],
#  ['What are the key differences in the detection mechanisms employed in superconducting quantum interference devices (SQUIDs) compared to liquid argon time projection chambers (LArTPCs) for identifying particles produced in high-energy collisions?'],
#  ['What are the implications of quark confinement on the formation of hadrons, and how does this relate to the strong force mediated by gluons?'],
#  ['What is the significance of the Higgs field in the context of spontaneous symmetry breaking and how does it relate to the mass generation of W and Z bosons in the Standard Model?'],
#  ['What is the significance of confinement in Quantum Chromodynamics, and how does it relate to the non-perturbative aspects of the theory?'],
#  ["How does Noether's theorem relate symmetries of a physical system to its conservation laws, and can you provide an example illustrating this connection?"],
#  ['What is the significance of the Laue equations in determining the orientation of a crystal lattice during X-ray diffraction experiments?'],
#  ['Explain the significance of the Fermi level in the band theory of solids and how it influences the electrical conductivity of materials at absolute zero temperature.'],
#  ['How do carrier concentration and mobility in a semiconductor material affect its conductivity at varying temperatures, and what role does doping play in this relationship?'],
#  ['What are the key differences in the mechanisms of superconductivity between conventional superconductors described by BCS theory and high-temperature superconductors, and how do these differences impact their respective critical temperatures and material properties?'],
#  ['What is the distinction between diamagnetism, paramagnetism, and ferromagnetism in terms of atomic structure and response to external magnetic fields?'],
#  ['What mechanisms underlie the difference in critical behavior between first-order and second-order phase transitions in ferromagnetic materials, and how do these mechanisms relate to the presence of symmetry breaking?'],
#  ['What are the implications of quantum confinement effects in nanomaterials on their electronic properties, and how can these effects be exploited in the design of nanoscale electronic devices?'],
#  ['What are the key physical processes that lead to the formation of a supernova, and how do these processes differ between Type I and Type II supernovae?'],
#  ['How do the variations in dark matter density profiles across different galaxy types influence the overall dynamics and formation of galactic structures?'],
#  ['What is the significance of the temperature fluctuations in the Cosmic Microwave Background radiation in relation to the formation of large-scale structures in the universe?'],
#  ['How does the observed isotropy of the Cosmic Microwave Background radiation support the existence of dark energy in the context of the accelerated expansion of the Universe?'],
#  ['What are the differences in the equations of state for matter in neutron stars versus those in black holes, and how do these differences impact the formation and evolution of each type of object?'],
#  ['What are the key atmospheric conditions required for an exoplanet to sustain long-term liquid water, and how might these conditions influence the potential for complex life evolution?'],
#  ['How does gravitational lensing provide evidence for the existence of dark matter, and what specific observations or measurements support this interpretation?'],
#  ['What are the key differences in particle behavior and energy levels between plasma and the other three fundamental states of matter: solid, liquid, and gas?'],
#  ['What are the key challenges in achieving and maintaining the necessary conditions for magnetic confinement fusion, particularly in relation to plasma stability and confinement time?'],
#  ['How do the governing equations of magnetohydrodynamics change when considering the effects of compressibility and how do these changes affect the stability criteria of MHD waves?'],
#  ['What are the key mechanisms behind the generation of magnetic fields in astrophysical plasmas, and how do these fields affect the dynamics of accretion disks around compact objects?'],
#  ['How do plasma-based propulsion systems, such as Hall effect thrusters, achieve efficient ionization and acceleration of propellant while minimizing energy losses in the process?'],
#  ['Consider a vector field \\(\\mathbf{F} = (y^2, x^2, z^2)\\). Compute the flux of \\(\\mathbf{F}\\) across the surface of the cube defined by \\(0 \\leq x, y, z \\leq 1\\) using the Divergence Theorem.'],
#  ['How does the Riemann curvature tensor relate to the geodesic deviation equation, and what does this relationship imply about the nature of spacetime in General Relativity?'],
#  ['What is the relationship between the symmetry group of a geometric object and its automorphism group, and how can this be illustrated through the example of the dihedral group \\( D_n \\) for a regular n-gon?'],
#  ['Let \\( f(z) \\) be an analytic function in the complex plane except for a finite number of poles. Consider the Fourier transform \\( \\hat{f}(\\xi) \\) of \\( f(x) \\) defined as \\( \\hat{f}(\\xi) = \\int_{-\\infty}^{\\infty} f(x) e^{-2\\pi i x \\xi} \\, dx \\). What is the relationship between the residues of \\( f(z) \\) at its poles and the asymptotic behavior of \\( \\hat{f}(\\xi) \\) as \\( |\\xi| \\to'],
#  ['How do you implement an efficient parallel algorithm for solving the time-dependent Schrödinger equation using the Split-Operator Fourier Transform method, and what considerations must be taken into account for ensuring numerical stability and accuracy?'],
#  ['How does the Landau-Zener model describe the quantum mechanical behavior of electrons in a time-dependent electric field near an avoided crossing, and what are the implications for adiabatic versus non-adiabatic transitions?'],
#  ['How does the no-cloning theorem impact the security of quantum key distribution protocols, and what implications does this have for the transmission of quantum information over potentially insecure channels?'],
#  ['What are the mechanisms of fatigue crack propagation in metallic materials, and how do microstructural features influence these mechanisms?'],
#  ['How does the interplay of electromagnetic radiation with biological tissues influence the efficacy of targeted cancer therapies, and what biophysical principles can be applied to optimize dose delivery while minimizing collateral damage to healthy cells?'],
#  ['What are the fundamental differences in electron-hole pair generation mechanisms in direct vs. indirect bandgap semiconductors, and how do these differences affect the efficiency of optoelectronic devices such as LEDs and solar cells?'],
#  ['What are the thermodynamic limitations associated with the efficiency of solar thermal power plants compared to concentrated solar power (CSP) systems, and how do these limitations impact their overall energy yield?']]
