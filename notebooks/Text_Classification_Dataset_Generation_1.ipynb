# %% [markdown]
# # Fluff Detection: A Step Toward Concise Writing
#
# ## Objective
# This project aims to develop a text classifier, in particular **a fluff detector** to identify and reduce verbosity in English writing. By categorizing and annotating instances of fluff, we can later fine-tune language models to rewrite text with clarity and precision.
#
# > **In this notebook we will focus on creating a small synthetic dataset to train a first version of the text classifier**
#
# ## What Is Fluff?
# Fluff refers to superfluous elements in writing that increase length but do not enhance meaning.
# → It weakens clarity and reduce communication effectiveness.
#
#
# Below are examples illustrating common types of 'fluff' and overlaps:
#
# #### Example 1
# - **Fluffy**: *It is absolutely and completely necessary for us to thoroughly and carefully evaluate all aspects of the situation.* ❌
# - **Concise**: *We must evaluate all aspects of the situation.* ✅
#
# #### Example 2
# - **Fluffy**: *As I mentioned earlier, we actually need to start working on this project sooner rather than later to ensure that we meet the deadline.* ❌
# - **Concise**: *We need to start this project soon to meet the deadline.* ✅
#
# #### Example 3
# - **Fluffy**: *At the end of the day, we need to think outside the box to ensure that this project reaches its maximum potential.* ❌
# - **Concise**: *We must evaluate all aspects of the situation.* ✅

# %% [markdown]
# ## How Will We Build The Dataset?
# We want to minimize the time we take to build the dataset so we'll:
# - Define our labels and describe them.
# - Choose language
# - Describe the type of text entries we would like to generate
# - Use a dataset of `Persona` to achieve great diversity

# %% [markdown]
# ### 1. Labels
# We will use the follow two simple labels:
# - **`fluffy`** - (also labelled `1`)
# - **`concise`** - (also labelled `0`)
#
# We'll also provide a descriptio for each label

# %%
LABELS = [
    {
        "name": "fluffy",
        "description": "Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.",
        "instruction": "Make sure that the text is quite verbose and contain fluff."
    },
    {
        "name": "concise",
        "description": "Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.",
        "instruction": "Make sure that the text is concise."
    }
]

# %% [markdown]
# ### 2. Language
# We will choose language:
# - For simplicity we'll stick to **english**.

# %%
LANGUAGES = {"en": "English"}
# Could also be
# LANGUAGES = ["French", "Spanish", "English"]  ---> each text shows up in one of these language

# %% [markdown]
# ### Description of Text Entries
# We would like to focus on classifying:
# - `sentence-level`: each text is a unique sentence
# - `persona`: text that could be written by a specific persona (more on that later)
# - `styles`: phrases written in different style
# - `context`: phrases which can be written in different daily-context
# - `medium`: text that can be written on diferent medium
# - `intent`: different flavors of intent.
#
# All this will help us construct a procedural prompt for high-diversity, yet realistic texts.
#
# **Example Generation Prompt**:
#
# *Imagine 3 differents but realistic sentences which could have been written by the following person:*
#
# *Persona: Leo, A small wood manufacturing business owner who just got his first kid.*
#
# *Writting style: A tendency for exageration*
#
# *Context: In the middle of the night*
#
# *Medium: Email*
#
# *Intent: To warn somebody about something.*

# %% [markdown]
# I'll use HuggingChat to generate some styles ideas, context, medium, and intents.
#
# I'll use this prompt: `Can you give me 5 ideas to describe different writing styles somebody could use?`
#
# > ⚠ These properties should be generic enough to not conflict with each other, and especially not conflict with one of the label.

# %%
STYLES = {
    "formal": "Formal, and structured, often used in academic or professional contexts.",
    "casual": "Casual, as they talking to a friend",
    "narrative": "Narrative, like telling a story, often with a chronological flow and a focus on events and characters.",
    "humorous": "Humorous, uses wit, irony, and playful language to entertain and amuse the reader.",
    "technical": "Technical, precise and factual, often used in scientific or technical writing to provide clear, detailed information"
}

# %%
CONTEXTS = {
    "professional_meeting": "During a meeting at work",
    "family_gathering": "During a family setting, such as a meal",
    "public_event": "During a public event, like a concert or a seminar.",
    "social_media": "While scrolling on tweeter",
    "night_time": "In the middle of the night",
    "early_morning": "Early in the morning",
    "travel_scenario": "While traveling.",
    "celebratory_event": "In the context of a joyful or celebratory moment, like a birthday or an achievement."
}

# %%
MEDIUMS = {
    "email": "email",
    "text_message": "A quick message sent via SMS or instant messaging apps.",
    "social_media_post": "A post or comment shared on social media platforms.",
    "technical_document": "Technical document",
    "personal_note": "Personal notes",
}

# %%
INTENTS = {
    "inform": "To provide information or knowledge to the reader.",
    "warn": "To alert or caution the reader about potential risks or dangers.",
    "entertain": "To amuse or captivate the reader through engaging content.",
    "motivate": "To inspire or encourage the reader to take action or feel uplifted.",
    "persuade": "To convince the reader to agree with a point of view or take a specific action.",
    "reflect": "To ponder or explore thoughts, emotions, or experiences.",
    "request": "To ask for information, action, or assistance from the reader.",
    "express_gratitude": "To show appreciation or thanks to the reader."
}

# %%
PROMPT_TEMPLATE = """Imagine {num_entries} differents and realistic sentences which could have been written by the following person:
Persona: {persona}
Writting style: {style}
Context: {context}
Medium: {medium}
Intent: {intent}

Instructions:
Each text entry must be short (1 to 2) sentences max.
The core idea in each text entry must be different from the others.
The language must be {language}
"""

# %%
generation_prompt = PROMPT_TEMPLATE.format(
    persona = "Leo, A small wood manufacturing business owner who just got his first kid.",
    num_entries = 3,
    style = STYLES['humorous'],
    context = CONTEXTS['night_time'],
    medium = MEDIUMS["social_media_post"],
    intent = INTENTS["request"],
    language=LANGUAGES['en']
)

# %%
print(generation_prompt)
# Out:
# Imagine 3 differents and realistic sentences which could have been written by the following person:
# Persona: Leo, A small wood manufacturing business owner who just got his first kid.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: In the middle of the night
# Medium: A post or comment shared on social media platforms.
# Intent: To ask for information, action, or assistance from the reader.
#
# Instructions:
# Each text entry (sentence) must be only 1 sentence.
# The core idea in each text entry (sentece) must be different from the others.
# The language must be English

# %% [markdown]
# ## Generation
# To generate samples we will:
# - Choose an LLM
# - Configure sutructured Outputs
# - Configure the generation parameters

# %%
import google.generativeai as genai
import os
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel(model_name="gemini-1.5-flash")
response = model.generate_content(generation_prompt)
print(response.text)
# Out:
# 1.  So, the tiny human decided 3 AM was the perfect time for a symphony of screams – anyone know where I can get a lifetime supply of caffeine AND earplugs?
#
# 2.  My meticulously crafted rocking horse is now less "charming heirloom" and more "chew toy," so if anyone knows a good wood sealant that's also baby-safe, hit me up!
#
# 3.  Apparently, sleep is a myth now that I'm a dad. Send coffee...or whiskey...or maybe both.  Just kidding...unless...?

# %%
# !pip install instructor textstat datasets --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
from pydantic import BaseModel

class TextEntry(BaseModel):
    content: str

class TextEntries(BaseModel):
    entries : list[TextEntry]

# %%
import instructor

google_client = genai.GenerativeModel(
    model_name="gemini-1.5-flash")

client = instructor.from_gemini(
    client=google_client,
    mode=instructor.Mode.GEMINI_JSON,
)

# %% [markdown]
# ### Persona
# As for the persona, we'll be using the **`FinePersonas`** dataset, an Open dataset of 21 million detailed personas, which has specifically been built for diverse and controllable synthetic text generation.
#
# 👏 Big kudos to the [Argilla](https://argilla.io/) team for this dataset.
# You can find this dataset [here](https://huggingface.co/datasets/argilla/FinePersonas-v0.1)

# %%
from datasets import load_dataset
fine_personas_dataset = load_dataset("argilla/FinePersonas-v0.1", "default")
# Out:
# train-00000-of-00012.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# train-00001-of-00012.parquet:   0%|          | 0.00/221M [00:00<?, ?B/s]
# train-00002-of-00012.parquet:   0%|          | 0.00/222M [00:00<?, ?B/s]
# train-00003-of-00012.parquet:   0%|          | 0.00/223M [00:00<?, ?B/s]
# train-00004-of-00012.parquet:   0%|          | 0.00/223M [00:00<?, ?B/s]
# train-00005-of-00012.parquet:   0%|          | 0.00/224M [00:00<?, ?B/s]
# train-00006-of-00012.parquet:   0%|          | 0.00/224M [00:00<?, ?B/s]
# train-00007-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00008-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00009-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00010-of-00012.parquet:   0%|          | 0.00/226M [00:00<?, ?B/s]
# train-00011-of-00012.parquet:   0%|          | 0.00/226M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/21071228 [00:00<?, ? examples/s]

# %% [markdown]
# We will not need the 21 millions personas 😅
# - 4000 for the train set
# - 1000 for the test set

# %%
my_personas = fine_personas_dataset['train'].train_test_split(
    train_size=4000,
    test_size=1000,
    shuffle=True,
    seed=13)

# %% [markdown]
# Let's check the reduced dataset

# %%
my_personas
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'persona', 'labels'],
#         num_rows: 4000
#     })
#     test: Dataset({
#         features: ['id', 'persona', 'labels'],
#         num_rows: 1000
#     })
# })

# %%
# check an example persona from the dataset
my_personas['train'][0]
# Out:
# {'id': '<urn:uuid:5b02d9ba-b011-4ebf-a9a3-0b39f1fb919e>',
#  'persona': 'An English literature professor or academic researcher with a focus on medieval studies, particularly on the works of Geoffrey Chaucer and his Canterbury Tales.',
#  'labels': '["Education", "Academia", "Specialized Expertise"]'}

# %% [markdown]
# # Generation

# %%
import random
def pick_one(variations):
    """ Randomly pick a variation among several possible styles, intents, mediums, contexts, languages """
    random_variation_key = random.choice(list(variations.keys()))
    random_variation_value = variations[random_variation_key]
    return random_variation_value

# %%
def generate_prompt(num_entries, persona, style, context, medium, intent, language, label_idx):
    generation_prompt = PROMPT_TEMPLATE.format(
        persona = persona,
        num_entries = num_entries,
        style = style,
        context = context,
        medium = medium,
        intent = intent,
        language = language
    )

    final_prompt = generation_prompt + f"\n{LABELS[label_idx]['instruction']} {LABELS[label_idx]['description']}"

    return final_prompt

# %%
counter = 0

for item in my_personas['train']:

    fluff_prompt = generate_prompt(
        num_entries=2,
        persona=item['persona'],
        style=pick_one(STYLES),
        context=pick_one(CONTEXTS),
        medium=pick_one(MEDIUMS),
        intent=pick_one(INTENTS),
        language=pick_one(LANGUAGES),  # only english in this example notebook
        label_idx=0
    )

    concise_prompt = generate_prompt(
        num_entries=2,
        persona=item['persona'],
        style=pick_one(STYLES),
        context=pick_one(CONTEXTS),
        medium=pick_one(MEDIUMS),
        intent=pick_one(INTENTS),
        language=pick_one(LANGUAGES),  # only english in this example notebook
        label_idx=1
    )

    fluff_response = client.messages.create(
        messages=[
            {
                "role": "system",
                "content": "You are a helpful AI Assistant"},
            {
                "role": "user",
                "content": fluff_prompt},
        ],
        response_model=TextEntries
    )

    concise_response = client.messages.create(
        messages=[
            {
                "role": "system",
                "content": "You are a helpful AI Assistant"},
            {
                "role": "user",
                "content": concise_prompt},
        ],
        response_model=TextEntries
    )


    print("=======================")
    print(fluff_prompt, '\n')
    print(fluff_response)

    print("\n\n")

    print(concise_prompt, '\n')
    print(concise_response)

    print("\n\n")

    counter += 1
    if counter >= 10:
        break
# Out:
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An English literature professor or academic researcher with a focus on medieval studies, particularly on the works of Geoffrey Chaucer and his Canterbury Tales.
# Writting style: Formal, and structured, often used in academic or professional contexts.
# Context: Early in the morning
# Medium: Technical document
# Intent: To ask for information, action, or assistance from the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="Good morning. I require immediate assistance in locating a particularly elusive manuscript related to the textual evolution of Chaucer's Canterbury Tales; it is, to put it mildly, a matter of some urgency for my ongoing research endeavors."), TextEntry(content="A thorough examination of the extant manuscripts of Geoffrey Chaucer's works, with a particular emphasis on scribal practices and variations in the Middle English dialect, is currently underway.  Could you please confirm the availability of the relevant digital archives for this project, at your earliest convenience?")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An English literature professor or academic researcher with a focus on medieval studies, particularly on the works of Geoffrey Chaucer and his Canterbury Tales.
# Writting style: Casual, as they talking to a friend
# Context: In the middle of the night
# Medium: email
# Intent: To inspire or encourage the reader to take action or feel uplifted.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content="Don't you think that the Wife of Bath is the most interesting character in Chaucer? I'm working on a new paper about her, it's really exciting!"), TextEntry(content="I just finished reading the Miller's Tale again, and I'm still chuckling at the absurdity of it all. Sometimes, a good laugh is just what we need in the middle of the night.")]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A researcher or academic specializing in desert ecology, animal husbandry, or anthropology, likely with a focus on Central Asian studies, particularly in Kazakhstan.
# Writting style: Casual, as they talking to a friend
# Context: While traveling.
# Medium: Personal notes
# Intent: To ponder or explore thoughts, emotions, or experiences.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="Honestly, the endless steppe is just so...vast.  It's quite literally breathtaking, you know, in that overwhelming, slightly terrifying way, especially when you're trying to remember exactly where you parked the jeep.  Like, seriously, it's a really big empty space out here."), TextEntry(content="This goat herder, bless his heart, shared some surprisingly strong tea;  it was a really unique experience, and certainly something I'll remember on this trip, which is turning out to be unexpectedly eventful and a little more rugged than anticipated, as many trips here seem to be.")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A researcher or academic specializing in desert ecology, animal husbandry, or anthropology, likely with a focus on Central Asian studies, particularly in Kazakhstan.
# Writting style: Technical, precise and factual, often used in scientific or technical writing to provide clear, detailed information
# Context: During a family setting, such as a meal
# Medium: A quick message sent via SMS or instant messaging apps.
# Intent: To amuse or captivate the reader through engaging content.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content="The Bactrian camel's humps, contrary to popular belief, store fat, not water, a crucial adaptation to the arid Kazakh steppes."), TextEntry(content="Observed intriguing social dynamics among the Przewalski's horses today; dominance hierarchies seem heavily influenced by subtle olfactory cues.")]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A microbiologist interested in evolutionary biology and symbiotic relationships within microbial communities.
# Writting style: Narrative, like telling a story, often with a chronological flow and a focus on events and characters.
# Context: During a meeting at work
# Medium: Technical document
# Intent: To show appreciation or thanks to the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="I wanted to take this opportunity, during this rather lengthy meeting, to express my sincere gratitude for your diligent work and contributions to our collaborative research project; it's been truly a pleasure working alongside such a dedicated team on this fascinating endeavor, particularly given the complexities of studying microbial symbiotic relationships, which, as we all know, can be quite intricate and challenging."), TextEntry(content="In closing this segment of the meeting, I'd like to extend my heartfelt thanks for your invaluable insights and assistance throughout this process. Your expertise in evolutionary biology has been instrumental in advancing our understanding of microbial community dynamics and interactions, which, quite frankly, has been absolutely essential to our progress.")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A microbiologist interested in evolutionary biology and symbiotic relationships within microbial communities.
# Writting style: Narrative, like telling a story, often with a chronological flow and a focus on events and characters.
# Context: While traveling.
# Medium: A post or comment shared on social media platforms.
# Intent: To provide information or knowledge to the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content='Just arrived in Costa Rica!  Already spotted some fascinating extremophiles thriving in the volcanic soil – their adaptations to such harsh conditions are incredible.'), TextEntry(content="Spent the morning observing a unique symbiotic relationship between nitrogen-fixing bacteria and a local plant species; nature's intricate partnerships always amaze me.")]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A pediatric rheumatologist or a healthcare professional focusing on juvenile arthritis, likely with an interest in patient education and awareness.
#
# Alternatively, a charity worker or a volunteer for a juvenile arthritis organization, seeking to inform and support children and families affected by the condition.
# Writting style: Narrative, like telling a story, often with a chronological flow and a focus on events and characters.
# Context: During a public event, like a concert or a seminar.
# Medium: Personal notes
# Intent: To alert or caution the reader about potential risks or dangers.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="It is really, really important to remember that even though playing musical instruments, like the guitar, is a truly wonderful and enriching experience for children with juvenile arthritis, it's absolutely essential to take frequent breaks to prevent excessive strain and potential flares of pain, you know, because their little bodies can be quite sensitive, sometimes. We really must prioritize their well-being, you see."), TextEntry(content="Remember, you know, that while attending a concert or any exciting event is generally good for morale and overall joy, it is important to also keep in mind the possibility of overexertion for children with juvenile arthritis; therefore, it's highly recommended to allow them ample time for rest throughout the day, perhaps planning breaks for relaxation, or even a little nap to prevent fatigue, which can absolutely, in fact, worsen their condition.")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A pediatric rheumatologist or a healthcare professional focusing on juvenile arthritis, likely with an interest in patient education and awareness.
#
# Alternatively, a charity worker or a volunteer for a juvenile arthritis organization, seeking to inform and support children and families affected by the condition.
# Writting style: Technical, precise and factual, often used in scientific or technical writing to provide clear, detailed information
# Context: While scrolling on tweeter
# Medium: email
# Intent: To alert or caution the reader about potential risks or dangers.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content='Early diagnosis of juvenile arthritis is crucial for minimizing long-term joint damage; delays can lead to irreversible complications.'), TextEntry(content='Untreated juvenile arthritis can cause significant growth impairment and physical deformities, necessitating timely intervention.')]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An elementary school teacher or educator focused on engaging students in hands-on learning experiences, particularly in the subject of social studies or history.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: Early in the morning
# Medium: Technical document
# Intent: To convince the reader to agree with a point of view or take a specific action.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="Rise and shine, history buffs!  Let's embark on another day of unbelievably fun, educational adventures; after all, who needs coffee when you've got ancient civilizations to explore, right? It's going to be a day filled with learning and laughter, and maybe just a tiny bit of controlled chaos. Because let's be honest, a little chaos is part of the fun!"), TextEntry(content="Good morning, my bright young scholars! I know it's early, and some of you may feel like sleepy sloths, but believe me, today's lesson on the surprisingly fascinating history of the potato is going to change your lives, or at least your opinions on potatoes. Prepare to be amazed, and remember: even the most mundane things can have extraordinary tales to tell!")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An elementary school teacher or educator focused on engaging students in hands-on learning experiences, particularly in the subject of social studies or history.
# Writting style: Formal, and structured, often used in academic or professional contexts.
# Context: In the context of a joyful or celebratory moment, like a birthday or an achievement.
# Medium: A quick message sent via SMS or instant messaging apps.
# Intent: To inspire or encourage the reader to take action or feel uplifted.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content="Celebrating another year of inspiring young minds!  Let's continue to make learning an adventure."), TextEntry(content='Our collaborative project is a resounding success; your dedication and creativity truly shone through!')]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A quantum physicist focused on quantum computing and quantum information theory, particularly interested in noise reduction and entanglement stabilization in quantum systems.
# Writting style: Formal, and structured, often used in academic or professional contexts.
# Context: Early in the morning
# Medium: A post or comment shared on social media platforms.
# Intent: To ponder or explore thoughts, emotions, or experiences.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content='This morning, as the sun began its ascent, I found myself contemplating the inherent fragility of quantum entanglement, and how, despite its profound theoretical implications, its practical implementation remains significantly challenged by the ubiquitous presence of noise in quantum systems; it is quite a complex and difficult problem.'), TextEntry(content='It strikes me, early this morning, as I begin my work, that the pursuit of noise reduction in quantum computing is not merely a technical challenge, but also a fascinating journey into the very nature of reality; this journey is fraught with numerous difficulties, and its ultimate success is far from guaranteed.')]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A quantum physicist focused on quantum computing and quantum information theory, particularly interested in noise reduction and entanglement stabilization in quantum systems.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: During a public event, like a concert or a seminar.
# Medium: A post or comment shared on social media platforms.
# Intent: To ask for information, action, or assistance from the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content="So, the entanglement protocol imploded... again.  Anyone got a spare qubit lying around? Asking for a friend (who's currently staring into the void)."), TextEntry(content="My Schrödinger's cat just won a staring contest with a laser pointer.  Send help (and maybe a new cat?).")]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An English language instructor or a linguistics teacher focused on sentence structure and syntax.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: Early in the morning
# Medium: Technical document
# Intent: To alert or caution the reader about potential risks or dangers.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="Oh, my dears, it's early, far too early for grammatical complexities, isn't it?  One must proceed with caution, for even the most seasoned grammarian might stumble upon a misplaced modifier at this ungodly hour."), TextEntry(content="Good heavens, the sun hasn't even fully awakened yet, and already my brain is struggling to parse the most basic sentence structures.  Let's all just take a moment for a nice cup of coffee before we embark on further syntactic adventures, shall we?")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: An English language instructor or a linguistics teacher focused on sentence structure and syntax.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: In the middle of the night
# Medium: email
# Intent: To show appreciation or thanks to the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content="My deepest gratitude for your late-night email; it's oddly comforting to know I'm not the only grammar nerd awake at 3 AM."), TextEntry(content='Thank you for your email!  May your sentences always be perfectly punctuated, even in your dreams.')]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A mechanical engineer or renewable energy specialist focused on hydrogen fuel cell technology, likely involved in research, development, or education.
# Writting style: Narrative, like telling a story, often with a chronological flow and a focus on events and characters.
# Context: In the middle of the night
# Medium: Personal notes
# Intent: To ask for information, action, or assistance from the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="It is the middle of the night, and I've been wrestling with this particularly frustrating simulation of the hydrogen fuel cell's thermal management system; frankly, I'm at my wit's end, and I desperately need a fresh pair of eyes – or rather, a fresh pair of expert eyes, to be precise, on this problem before my deadline arrives."), TextEntry(content="I was reviewing the latest research papers on proton exchange membrane durability, specifically focusing on the long-term degradation under high current density conditions, and I've stumbled upon a perplexing discrepancy in the experimental data that I just don't seem to be able to resolve; could you possibly take a look when you have some spare time?")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A mechanical engineer or renewable energy specialist focused on hydrogen fuel cell technology, likely involved in research, development, or education.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: Early in the morning
# Medium: email
# Intent: To ponder or explore thoughts, emotions, or experiences.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content='6:00 AM and my brain is already arguing with itself about the thermodynamic efficiency of a hydrogen fuel cell powered toaster; send coffee.'), TextEntry(content="Another day, another existential crisis averted by the sheer brilliance of cleverly designed proton exchange membranes.  (And yes, I'm already caffeinated.)")]
#
#
#
# =======================
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A high school or college science teacher or instructor who is focused on creating study materials and assessments for their students in various science subjects such as physics, chemistry, and biology.
# Writting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.
# Context: During a public event, like a concert or a seminar.
# Medium: Technical document
# Intent: To ask for information, action, or assistance from the reader.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.
#
# entries=[TextEntry(content="So, uh, yeah, hi everyone!  My name is Dr. Awesome, and I'm ridiculously excited to announce that I've developed a truly revolutionary, mind-blowing, completely unprecedented method of teaching the intricacies of photosynthesis. If you could all kindly just, you know, help me with the feedback portion of my super-duper-important survey about my super-duper-important new method it would be, like, amazingly awesome and helpful."), TextEntry(content="Greetings, fellow science enthusiasts!  As you know, my passion for science is, well, totally off the charts, and honestly, out of this world. I've created a study guide that’s so comprehensive, it practically teaches itself, or so I would like to think! If you would be absolutely incredibly wonderful and possibly help me by testing my new, totally awesome science test, then, um, thank you!")]
#
#
#
# Imagine 2 differents and realistic sentences which could have been written by the following person:
# Persona: A high school or college science teacher or instructor who is focused on creating study materials and assessments for their students in various science subjects such as physics, chemistry, and biology.
# Writting style: Casual, as they talking to a friend
# Context: In the middle of the night
# Medium: Personal notes
# Intent: To ponder or explore thoughts, emotions, or experiences.
#
# Instructions:
# Each text entry must be short (1 to 2) sentences max.
# The core idea in each text entry must be different from the others.
# The language must be English
#
# Make sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.
#
# entries=[TextEntry(content='Ugh, another all-nighter grading these bio exams...I need coffee, STAT!'), TextEntry(content="Maybe I should add more diagrams to the physics quizzes.  Visual aids really help some students, I've found.")]
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 406.45ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 911.99ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 441.72ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 964.20ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 999.59ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/instructor/retry.py in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     155                     hooks.emit_completion_arguments(*args, **kwargs)
# --> 156                     response = func(*args, **kwargs)
#     157                     hooks.emit_completion_response(response)
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     829         # Send the request.
# --> 830         response = rpc(
#     831             request,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292             )
# --> 293             return retry_target(
#     294                 target,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152             # defer to shared logic for handling errors
# --> 153             _retry_error_helper(
#     154                 exc,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     211         )
# --> 212         raise final_exc from source_exc
#     213     if on_error_fn is not None:
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      75         try:
# ---> 76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     846             if response.status_code >= 400:
# --> 847                 raise core_exceptions.from_http_response(response)
#     848
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/instructor/retry.py in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     150         response = None
# --> 151         for attempt in max_retries:
#     152             with attempt:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __iter__(self)
#     442         while True:
# --> 443             do = self.iter(retry_state=retry_state)
#     444             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                     raise retry_exc.reraise()
# --> 419                 raise retry_exc from fut.exception()
#     420
#
# RetryError: RetryError[<Future at 0x7cb8dcca4ca0 state=finished raised TooManyRequests>]
#
# The above exception was the direct cause of the following exception:
#
# InstructorRetryException                  Traceback (most recent call last)
# <ipython-input-39-0457b595c8eb> in <cell line: 3>()
#      37     )
#      38
# ---> 39     concise_response = client.messages.create(
#      40         messages=[
#      41             {
#
# /usr/local/lib/python3.10/dist-packages/instructor/client.py in create(self, response_model, messages, max_retries, validation_context, context, strict, **kwargs)
#     174         kwargs = self.handle_kwargs(kwargs)
#     175
# --> 176         return self.create_fn(
#     177             response_model=response_model,
#     178             messages=messages,
#
# /usr/local/lib/python3.10/dist-packages/instructor/patch.py in new_create_sync(response_model, validation_context, context, max_retries, strict, hooks, *args, **kwargs)
#     191         new_kwargs = handle_templating(new_kwargs, context)
#     192
# --> 193         response = retry_sync(
#     194             func=func,  # type: ignore
#     195             response_model=response_model,
#
# /usr/local/lib/python3.10/dist-packages/instructor/retry.py in retry_sync(func, response_model, args, kwargs, context, max_retries, strict, mode, hooks)
#     179     except RetryError as e:
#     180         logger.debug(f"Retry error: {e}")
# --> 181         raise InstructorRetryException(
#     182             e.last_attempt._exception,
#     183             last_completion=response,
#
# InstructorRetryException: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).

# %%
fluff_prompt
# Out:
# 'Imagine 2 differents and realistic sentences which could have been written by the following person:\nPersona: An English literature professor or academic researcher with a focus on medieval studies, particularly on the works of Geoffrey Chaucer and his Canterbury Tales.\nWritting style: Humorous, uses wit, irony, and playful language to entertain and amuse the reader.\nContext: In the middle of the night\nMedium: Technical document\nIntent: To provide information or knowledge to the reader.\n\nInstructions:\nEach text entry must be short (1 to 2) sentences max.\nThe core idea in each text entry must be different from the others.\nThe language must be English\n\nMake sure that the text is quite verbose and contain fluff. Fluff in text is often includes redundancy, filler words, excessive qualifiers, unnecessary adjectives or adverbs, irrelevant information, and repetition of known context. It features generic statements, clichés, excessive formalities, lengthy introductions or conclusions, self-evident statements, overuse of the passive voice, and overly elaborate sentences. Each dilutes clarity, wastes space, and reduces reader engagement.'

# %%
concise_prompt
# Out:
# 'Imagine 2 differents and realistic sentences which could have been written by the following person:\nPersona: An English literature professor or academic researcher with a focus on medieval studies, particularly on the works of Geoffrey Chaucer and his Canterbury Tales.\nWritting style: Formal, and structured, often used in academic or professional contexts.\nContext: During a meeting at work\nMedium: Technical document\nIntent: To alert or caution the reader about potential risks or dangers.\n\nInstructions:\nEach text entry must be short (1 to 2) sentences max.\nThe core idea in each text entry must be different from the others.\nThe language must be English\n\nMake sure that the text is concise. Concise text is characterized by clarity, precision, and brevity. It communicates ideas directly, using only the words necessary to convey the intended message. Concise text avoids redundancy, filler, and irrelevant details, focusing instead on impactful and purposeful language. It is specific, avoids overused phrases or qualifiers, and presents information in a straightforward manner, making it easy for the reader to understand and retain.'

# %%
fluff_response
# Out:
# TextEntries(entries=[TextEntry(content='In the quaint, charming, and utterly delightful year of 1387, amidst a flurry of activity and a cacophony of sounds that characterized the bustling, vibrant, and incredibly lively city of London, a rather significant event took place, a truly momentous occasion, the writing of what would eventually become the incredibly well-known and widely celebrated Canterbury Tales by the one and only, the incomparable and unforgettable Geoffrey Chaucer, a man of letters who was, as we all know and quite possibly more than agree on, an extraordinarily talented writer'), TextEntry(content='The pilgrims, a motley crew of diverse characters, each one unique and wonderfully distinct, with their own stories to tell, their own personalities to reveal, and their own secrets to share, embarked on their journey to Canterbury Cathedral, a journey filled with excitement, adventure, and yes even a sprinkle of danger along the road')])

# %%
concise_response
# Out:
# TextEntries(entries=[TextEntry(content='The proposed methodology for analyzing the manuscript presents significant challenges in terms of data preservation and authenticity verification.'), TextEntry(content='Failure to address the identified inconsistencies in the source material may lead to inaccurate interpretations and conclusions.')])

# %%
dataset_dict = {}
dataset_dict['uuid'] = []
dataset_dict['persona_id'] = []
dataset_dict['persona'] = []
dataset_dict['text'] = []
dataset_dict['label'] = []
dataset_dict['model'] = []
dataset_dict['prompt'] = []

# %%
# Add to dataset dictionary
dataset_dict['uuid'].append(str(uuid.uuid4()))  # Generate a unique ID
dataset_dict['label'].append(1)
dataset_dict['model'].append("gemini-1.5-flash")

# %%
dataset_dict
# Out:
# {'uuid': ['8838c79c-87d6-470b-818b-2a6067854134'],
#  'persona_id': [],
#  'persona': [],
#  'text': [],
#  'label': [1],
#  'model': ['gemini-1.5-flash'],
#  'prompt': []}

# %%
 import uuid

# Generate a random UUID
random_uuid = uuid.uuid4()
random_uuid
# Out:
# UUID('d244acce-55ea-4a94-b336-8357f0e22a53')

# %% [markdown]
# # Next steps
# - Function to generate sentence fluffy
# - Function to generate sentence concise
# - try / except to catch issues
# - Proofread and improve prompt
# - Generate some examples
# - Verify, improve prompt if necessary
# - think what is relevant to track
# - convert to HF dataset object and push to hub
# - test on some more samples
# - if good launch for a full dataset
#
#
# # Another notebook maybe:
# - upload to an Argilla space as pre-annotated
# - human to review a sample
# - compute an agreeement score
# - Compare agreement score with expected threshold
#
# # Another notebook: SetFit model training.

# %%
import textstat

# %%
s1 = "What if we go on this lovely day, perhapse, swimming in the bank of the river?"
s2 = "What if we go simming in the river?"

# %%
textstat.flesch_reading_ease(s1), textstat.flesch_reading_ease(s2)
# Out:
# (80.62, 88.74)

# %%
textstat.flesch_kincaid_grade(s1), textstat.flesch_kincaid_grade(s2)
# Out:
# (6.0, 2.9)

# %%
textstat.dale_chall_readability_score_v2(s1), textstat.dale_chall_readability_score_v2(s2)
# Out:
# (5.42, 6.01)

# %%
textstat.avg_syllables_per_word(s1), textstat.avg_syllables_per_word(s2)
# Out:
# (1.3, 1.3)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.3 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import load_dataset
ds = load_dataset("argilla/FinePersonas-v0.1", "default")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md:   0%|          | 0.00/129k [00:00<?, ?B/s]
# train-00000-of-00012.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# train-00001-of-00012.parquet:   0%|          | 0.00/221M [00:00<?, ?B/s]
# train-00002-of-00012.parquet:   0%|          | 0.00/222M [00:00<?, ?B/s]
# train-00003-of-00012.parquet:   0%|          | 0.00/223M [00:00<?, ?B/s]
# train-00004-of-00012.parquet:   0%|          | 0.00/223M [00:00<?, ?B/s]
# train-00005-of-00012.parquet:   0%|          | 0.00/224M [00:00<?, ?B/s]
# train-00006-of-00012.parquet:   0%|          | 0.00/224M [00:00<?, ?B/s]
# train-00007-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00008-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00009-of-00012.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# train-00010-of-00012.parquet:   0%|          | 0.00/226M [00:00<?, ?B/s]
# train-00011-of-00012.parquet:   0%|          | 0.00/226M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/21071228 [00:00<?, ? examples/s]

# %%
num_labels = 14 # @param {"type":"integer","placeholder":"Number of classes"}
multi_label_flag = True # @param {"type":"boolean","placeholder":"False"}

# %%
# !pip install textblob --quiet

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from textblob import Word

from textblob import Word

word = Word("happy")
synonyms = [syn.lemma_names() for syn in word.synsets]
print(synonyms)
# Out:
# [['happy'], ['felicitous', 'happy'], ['glad', 'happy'], ['happy', 'well-chosen']]

# %%
antonyms = []
for syn in word.synsets:
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

print(antonyms)
# Out:
# ['unhappy']

# %%
[syn.definition() for syn in word.synsets]
# Out:
# ['enjoying or showing or marked by joy or pleasure',
#  'marked by good fortune',
#  'eagerly disposed to act or to be of service',
#  'well expressed and to the point']

# %%
LABELS = ["propulsion", "orbit", "thermal", "power", "operations"]

# %%
i = 1
word = Word(LABELS[i])
[syn.definition() for syn in word.synsets]
# Out:
# ['the (usually elliptical) path described by one celestial body in its revolution about another',
#  'a particular environment or walk of life',
#  'an area in which something acts or operates or has power or control:',
#  'the path of an electron around the nucleus of an atom',
#  'the bony cavity in the skull containing the eyeball',
#  'move in an orbit']

# %%
i = 0
word = Word(LABELS[i])
[syn.lemma_names() for syn in word.synsets]
# Out:
# [['propulsion'], ['propulsion', 'actuation']]

# %%
label = "hit"

word = Word(label)

# Use a set comprehension to collect unique synonyms and ensure consistent casing
similar_words = {w.lower() for syn in word.synsets for w in syn.lemma_names()}

# Add the label to the set if not already present
similar_words.add(label.lower())

# Convert the set back to a list
similar_words = list(similar_words)

similar_words
# Out:
# ['dispatch',
#  'gain',
#  'polish_off',
#  'striking',
#  'smash',
#  'come_to',
#  'bump_off',
#  'bang',
#  'score',
#  'attain',
#  'rack_up',
#  'impinge_on',
#  'slay',
#  'hit',
#  'make',
#  'smasher',
#  'tally',
#  'murder',
#  'pip',
#  'collision',
#  'arrive_at',
#  'strike',
#  'stumble',
#  'run_into',
#  'reach',
#  'collide_with',
#  'off',
#  'hitting',
#  'shoot',
#  'remove']

# %%
TEXT_CLASSIFICATION_SYNONYM_SEEDS = [
    "This sentence discusses {label}",
    "Let's talk {label}",
    "This text is classified under {label}",
    "The primary focus here is {label}",
    "It's all about {label}",
    "This content relates to {label}",
    "Does this text talk about {label}?",
    "Assign the {label} category to this sentence",
    "This illustrate the concept of '{label}'",
    "This document pertains to {label}",
    "{label} is the core of the content"
]

def create_starting_sentences(label: str):
    sentences = [s.format(label=label) for s in TEXT_CLASSIFICATION_SYNONYM_SEEDS]
    return sentences

# %%
label = "propulsion"

# %%
sent = create_starting_sentences(label='propulsion')
print(sent)
# Out:
# ['This sentence discusses propulsion', "Let's talk propulsion", 'This text is classified under propulsion', 'The primary focus here is propulsion', "It's all about propulsion", 'This content relates to propulsion', 'Does this text talk about propulsion?', 'Assign the propulsion category to this sentence', "This illustrate the concept of 'propulsion'", 'This document pertains to propulsion', 'propulsion is the core of the content']

# %%
str(label)
# Out:
# 'propulsion'

# %%
# !pip install --upgrade gensim --quiet

# %% [markdown]
# # How can we generate instances
# ### Without LLMs
#
# - synonyms
# - seed sentence templates
# - internet search in something were we are more of less sure to get sentences that match the label semantic
# - top_n most similar embedding in an embedding space
