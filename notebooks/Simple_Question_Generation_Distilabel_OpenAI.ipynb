# %% [markdown]
# # Easy Question Generation with distilabel and OpenAI
# In this notebook I show you how to use OpenAI in distilabel to generate a bunch of questions.
#
# *Why are we using distilabel? couldn't we just do it with `openai`? Yes we could, here I just would like to introduce distilabel.*

# %% [markdown]
# ## Install distilabel and OpenAI setup
# - Below is how to install distilabel within a Google Colab notebook
# - You need to configure the OpenAI key. If you have doubts, look at this notebook [here](https://github.com/patrickfleith/datapipes/blob/main/How_to_use_an_OpenAI_Chat_model.ipynb)

# %%
# !pip install distilabel --upgrade --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.2/442.2 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import openai, distilabel
from distilabel.llms import OpenAILLM
from google.colab import userdata
from itertools import product

# %%
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
# printing my version such you can check yours
print(f"Open AI version: {openai.__version__}")
print(f"Distilabel version: {distilabel.__version__}")
# Out:
# Open AI version: 1.57.4
# Distilabel version: 1.4.2

# %% [markdown]
# ## Configuration
# For this demo notebook we want to generate **questions of several difficulty levels for given topics**
#
# So we let you define some
# - difficulty levels: no more than 4 is recommended.
# - topics: you could be more specific and have a much longer list than the one below
#
# 💡 I created my list using an LLM. You see how it starts to be interesting?

# %%
# config
levels = ["easy", "typical", "difficult", "hardcore"]

topics = [
    # Classical Mechanics
    "Newton's Laws of Motion",
    "Kinematics and Dynamics",
    "Work, Energy, and Power",
    "Momentum and Collisions",
    "Rotational Motion and Angular Momentum",
    "Gravitation and Orbital Mechanics",
    "Fluid Mechanics",
    "Harmonic Motion and Oscillations",
    "Lagrangian and Hamiltonian Mechanics",

    # Thermodynamics and Statistical Mechanics
    "Temperature and Heat",
    "Laws of Thermodynamics",
    "Entropy and the Second Law",
    "Thermodynamic Processes",
    "Heat Engines and Refrigerators",
    "Statistical Mechanics and Probability",
    "Kinetic Theory of Gases",
    "Phase Transitions and Critical Phenomena",

    # Electromagnetism
    "Electrostatics (Coulomb’s Law, Electric Fields, Potential)",
    "Electric Circuits (Ohm’s Law, Kirchhoff’s Laws, AC/DC Circuits)",
    "Magnetostatics (Magnetic Fields, Biot-Savart Law, Ampère's Law)",
    "Electromagnetic Induction (Faraday's Law, Lenz’s Law)",
    "Maxwell's Equations",
    "Electromagnetic Waves and Light",
    "Optics (Geometric and Wave Optics)",

    # Quantum Mechanics
    "Wave-Particle Duality",
    "Schrödinger Equation",
    "Quantum States and Operators",
    "Quantum Harmonic Oscillator",
    "Angular Momentum and Spin",
    "Quantum Tunneling",
    "Heisenberg Uncertainty Principle",
    "Quantum Entanglement",
    "Atomic and Molecular Physics",

    # Relativity
    "Special Relativity (Time Dilation, Length Contraction, E=mc²)",
    "General Relativity (Gravitational Waves, Black Holes, Space-Time Curvature)",
    "Lorentz Transformations",
    "Relativistic Dynamics",

    # Nuclear and Particle Physics
    "Radioactivity and Nuclear Decay",
    "Nuclear Reactions and Fusion",
    "Particle Accelerators and Detectors",
    "Fundamental Particles (Quarks, Leptons, Bosons)",
    "The Standard Model of Particle Physics",
    "Quantum Chromodynamics (QCD)",
    "Symmetry and Conservation Laws",

    # Condensed Matter Physics
    "Crystallography and Lattice Structures",
    "Band Theory of Solids",
    "Semiconductors and Electronics",
    "Superconductivity",
    "Magnetism and Magnetic Materials",
    "Phase Transitions (Ferromagnetic, Antiferromagnetic, etc.)",
    "Nanomaterials and Nanotechnology",

    # Astrophysics and Cosmology
    "The Structure of Stars and Stellar Evolution",
    "Galaxies and Dark Matter",
    "Big Bang Theory and Cosmic Microwave Background",
    "Expansion of the Universe and Dark Energy",
    "Black Holes and Neutron Stars",
    "Exoplanets and Habitability",
    "Gravitational Lensing",

    # Plasma Physics
    "Basics of Plasma States",
    "Plasma Confinement and Fusion Energy",
    "Magnetohydrodynamics (MHD)",
    "Space and Astrophysical Plasmas",
    "Plasma Applications (Lasers, Propulsion)",

    # Mathematical Physics
    "Vector Calculus and Differential Equations",
    "Tensor Analysis and General Relativity",
    "Group Theory and Symmetry",
    "Complex Analysis and Fourier Transforms",
    "Computational Physics and Numerical Methods",

    # Modern and Applied Physics
    "Solid-State Physics",
    "Quantum Computing and Information Theory",
    "Materials Science",
    "Biophysics and Medical Physics",
    "Optoelectronics and Photonics",
    "Renewable Energy Technologies"
]

# %%
print(f"A total of {len(levels)*len(topics)} questions will be generated")
# Out:
# A total of 296 questions will be generated

# %% [markdown]
# # The TICMI framework
#
# This is the way I like to think of LLM usage *in general* (it largely depends on the actually used framework, LLM, open-source vs closed source etc...). But often the ingredients are the same:
#
# - **Templates**: these are templates used to build prompt specific instructions.
#     - For example: `"Do the following task: {task}. Answer in {language}"`
#
# - **Instructions**: these are what I like to inject in templates.
#     - For example: `task = "solve the equation for x"` or `language="French"`.
#
# - **Constructor**: take a prompt template + instructions to make a prompt
#     - For example: our prompt would become `Do the following task: solve the equation for x. Answer in French.`
#
# - **Messages**: Often model like a list of messages with alternating roles (user/assistant or similar). Here I used the created prompt to make the messages.
#     - For example:
# ```
# [
#     {'role': 'system', 'content': '...'},
#     {'role': 'user', 'content': '...'}
# ]
# ```
#
# - **Model**: Here you would load the model, choosing which model, and loading potentially some configuration needed (like API key) or other model-specific parameters.
#
#
# - **Inference**: Here you pass the `messages` to the `model` along with possibly some specific parameters for that inference (temperature, max_token, etc...)

# %%
# prompt template
prompt_template = "Ask me a {level} question about {topic}. Only respond with the question, nothing else."

# prompt constructor
prompts = [prompt_template.format(level=level, topic=topic) for level, topic in product(levels, topics)]

# messages
inputs = [[{"role": "user", "content": prompt}] for prompt in prompts]

# model
llm = OpenAILLM(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
llm.load()

# inference
outputs = llm.generate_outputs(inputs=inputs, temperature=0.9)
outputs
# Out:
# [['What is the first law of motion that states an object at rest stays at rest unless acted upon by an external force?'],
#  ['What is the formula for calculating the distance traveled by an object under uniform acceleration?'],
#  ['What is the formula for calculating kinetic energy?'],
#  ['What is the law of conservation of momentum?'],
#  ['What is the formula for calculating angular momentum (L) of an object rotating around an axis?'],
#  ['What is the force that pulls objects toward each other due to their mass?'],
#  ['What is the definition of viscosity in fluid mechanics?'],
#  ['What is the definition of simple harmonic motion?'],
#  ['What is the principle of least action in the context of Lagrangian mechanics?'],
#  ['What is the freezing point of water in degrees Celsius?'],
#  ['What is the first law of thermodynamics commonly known as?'],
#  ['What does the Second Law of Thermodynamics state about the direction of spontaneous processes in isolated systems?'],
#  ['What is the term for a process in which heat is added to a system without doing any work on it?'],
#  ['What is the main purpose of a heat engine?'],
#  ['What is the definition of the partition function in statistical mechanics?'],
#  ['What is the main assumption of the kinetic theory of gases regarding the motion of gas particles?'],
#  ['What is a phase transition?'],
#  ["What is the formula for Coulomb's Law that describes the force between two point charges?"],
#  ["What is the formula for calculating voltage using Ohm's Law?"],
#  ['What is the Biot-Savart Law used for in magnetostatics?'],
#  ["What is Faraday's Law of Electromagnetic Induction?"],
#  ["What are the four equations that make up Maxwell's Equations?"],
#  ['What is the speed of light in a vacuum?'],
#  ['What is the law that describes the relationship between the angles of incidence and refraction when light passes from one medium to another?'],
#  ['What is wave-particle duality?'],
#  ['What does the Schrödinger Equation describe in quantum mechanics?'],
#  ['What is the principle of superposition in quantum mechanics?'],
#  ['What is the energy of the ground state of a quantum harmonic oscillator?'],
#  ['What is the formula for calculating the angular momentum of a rotating object?'],
#  ['What is quantum tunneling?'],
#  ['What does the Heisenberg Uncertainty Principle state about the relationship between position and momentum?'],
#  ['What is quantum entanglement?'],
#  ['What is the smallest unit of an element that retains the properties of that element?'],
#  ['What happens to time for an object moving at a high speed compared to an observer at rest?'],
#  ['What phenomenon do gravitational waves represent in the context of General Relativity?'],
#  ['What is the primary purpose of Lorentz transformations in physics?'],
#  ['What happens to the mass of an object as its speed approaches the speed of light according to relativistic dynamics?'],
#  ['What is the term used to describe the time it takes for half of a radioactive substance to decay?'],
#  ['What is the primary process that powers the Sun and other stars?'],
#  ['What is the primary purpose of a particle accelerator?'],
#  ['What is the smallest building block of matter that combines to form protons and neutrons?'],
#  ['What are the four fundamental forces described in the Standard Model of Particle Physics?'],
#  ['What is the primary force that governs the interactions between quarks and gluons in Quantum Chromodynamics (QCD)?'],
#  ['What is the principle of conservation of energy in relation to symmetry?'],
#  ['What is the basic repeating unit of a crystal lattice called?'],
#  ['What is the difference between conductors, insulators, and semiconductors in terms of their band gaps?'],
#  ['What is the main purpose of a diode in an electronic circuit?'],
#  ['What is superconductivity?'],
#  ['What is the term used to describe materials that are strongly attracted to magnets?'],
#  ['What is the main characteristic that distinguishes a ferromagnetic material from an antiferromagnetic material?'],
#  ['What are nanomaterials?'],
#  ['What is the primary fuel that stars use for nuclear fusion during their main sequence phase?'],
#  ['What is the name of the galaxy that is closest to the Milky Way?'],
#  ['What is the Cosmic Microwave Background (CMB) and why is it significant in the study of the Big Bang Theory?'],
#  ['What is the main effect of dark energy on the expansion of the universe?'],
#  ['What is the main difference between a black hole and a neutron star in terms of their formation?'],
#  ['What is an exoplanet?'],
#  ['What is gravitational lensing?'],
#  ['What is plasma often referred to as in terms of its state of matter classification?'],
#  ['What is the primary goal of plasma confinement in fusion energy research?'],
#  ['What does MHD stand for?'],
#  ['What is the main source of energy for stars, including our Sun?'],
#  ['What is one common application of plasma in laser technology?'],
#  ['What is the gradient of the scalar function \\( f(x, y) = x^2 + y^2 \\)?'],
#  ['What is a tensor, and how is it used to describe physical quantities in General Relativity?'],
#  ['What is a group in the context of group theory?'],
#  ['What is the Laplace transform of the function \\( f(t) = e^{at} \\) for \\( t \\geq 0 \\)?'],
#  ['What is the purpose of using numerical methods in computational physics?'],
#  ['What is the primary difference between conductors, insulators, and semiconductors in terms of their electrical conductivity?'],
#  ['What is a qubit?'],
#  ['What is the primary difference between metals and nonmetals in terms of electrical conductivity?'],
#  ['What is the primary purpose of an X-ray in medical imaging?'],
#  ['What is the primary function of a laser diode in optoelectronics?'],
#  ['What is the primary source of energy for solar panels?'],
#  ["What are Newton's three laws of motion and how do they apply to everyday situations?"],
#  ["A car accelerates uniformly from rest to a speed of 25 m/s over a distance of 200 meters. What is the car's acceleration?"],
#  ['What is the work done when a force of 10 N displaces an object 5 meters in the direction of the force?'],
#  ['A 2,000 kg car traveling at 15 m/s collides with a stationary 1,000 kg car. If the collision is perfectly inelastic, what is the final velocity of the two car system immediately after the collision?'],
#  ['What is the relationship between torque and angular momentum in a rotating system?'],
#  ['What is the relationship between the gravitational force and the distance between two objects in space?'],
#  ['What is the difference between laminar and turbulent flow?'],
#  ['What is the relationship between the period of a simple harmonic oscillator and its mass and spring constant?'],
#  ['What is the principle of least action and how does it relate to Lagrangian mechanics?'],
#  ['What is the difference between temperature and heat?'],
#  ['What is the first law of thermodynamics and how does it relate to the conservation of energy?'],
#  ['What is the significance of the Second Law of Thermodynamics in relation to entropy in a closed system?'],
#  ['What is the difference between an isothermal process and an adiabatic process in thermodynamics?'],
#  ['What is the difference between the coefficient of performance (COP) of a refrigerator and the efficiency of a heat engine?'],
#  ['What is the significance of the partition function in statistical mechanics?'],
#  ['What is the relationship between the temperature of a gas and the average kinetic energy of its particles according to the kinetic theory of gases?'],
#  ['What is the significance of the critical exponent in describing phase transitions?'],
#  ['What is the magnitude of the electric force between two point charges of +3 µC and -2 µC separated by a distance of 0.5 m?'],
#  ["What is the relationship between voltage, current, and resistance as described by Ohm's Law?"],
#  ['What is the expression for the magnetic field at a point due to a long straight current-carrying wire using the Biot-Savart Law?'],
#  ["What is Faraday's Law of Electromagnetic Induction, and how does it relate to Lenz's Law?"],
#  ["What is the physical significance of Gauss's law in electrostatics?"],
#  ['What is the relationship between wavelength, frequency, and speed of electromagnetic waves?'],
#  ['What is the difference between reflection and refraction of light?'],
#  ['What is wave-particle duality and how does it relate to the behavior of photons and electrons?'],
#  ['What is the significance of the time-dependent Schrödinger Equation in quantum mechanics?'],
#  ['What is the significance of the wave function in describing a quantum state, and how does it relate to operators in quantum mechanics?'],
#  ['What is the significance of the zero-point energy in the quantum harmonic oscillator?'],
#  ['What is the relationship between angular momentum and spin in quantum mechanics?'],
#  ['What is quantum tunneling, and how does it differ from classical particle behavior?'],
#  ["What does the Heisenberg Uncertainty Principle state about the relationship between a particle's position and momentum?"],
#  ['What is quantum entanglement and how does it differ from classical correlations?'],
#  ['What is the significance of the quantum mechanical model of the atom compared to the classical model?'],
#  ['What is the effect of time dilation on a clock moving relative to an observer compared to a clock at rest with respect to that observer?'],
#  ['What is the significance of the event horizon in the context of black holes and how does it relate to the concept of space-time curvature?'],
#  ['What is the significance of the Lorentz transformation in the theory of special relativity?'],
#  ['How does the relativistic momentum of an object change as its velocity approaches the speed of light?'],
#  ['What is the difference between alpha decay, beta decay, and gamma decay in terms of the particles emitted and their effects on the atomic number and mass number of the parent nucleus?'],
#  ['What are the primary conditions required for nuclear fusion to occur in stars?'],
#  ['What are the key differences between a collider and a fixed-target particle accelerator?'],
#  ['What are the six types of quarks, and how do they differ from leptons?'],
#  ['What are the fundamental particles that make up the Standard Model of Particle Physics?'],
#  ['What are the fundamental particles and forces involved in Quantum Chromodynamics?'],
#  ["How do Noether's theorem and the principle of symmetry relate to the conservation laws in physics?"],
#  ['What are the differences between cubic, tetragonal, and orthorhombic lattice structures in crystallography?'],
#  ['What is the difference between conductors, insulators, and semiconductors in terms of band theory?'],
#  ['What are the main differences between n-type and p-type semiconductors?'],
#  ['What is the Meissner effect in superconductors?'],
#  ['What are the differences between ferromagnetic, paramagnetic, and diamagnetic materials?'],
#  ['What are the key differences between first-order and second-order phase transitions in the context of ferromagnetism and antiferromagnetism?'],
#  ['What are some potential applications of nanomaterials in medicine?'],
#  ['What are the main stages of stellar evolution for a Sun-like star?'],
#  ['What role does dark matter play in the formation and structure of galaxies?'],
#  ['What is the significance of the Cosmic Microwave Background radiation in supporting the Big Bang Theory?'],
#  ['What role does dark energy play in the accelerated expansion of the universe?'],
#  ['What are the key differences between black holes and neutron stars in terms of their formation and characteristics?'],
#  ['What key factors determine the habitability of an exoplanet?'],
#  ['What is gravitational lensing and how does it occur?'],
#  ['What are the key characteristics that differentiate plasma from the other three main states of matter: solid, liquid, and gas?'],
#  ['What are the main methods used for plasma confinement in fusion reactors?'],
#  ['What are the fundamental equations governing magnetohydrodynamics and how do they relate to fluid dynamics and electromagnetic fields?'],
#  ['What are the primary mechanisms responsible for the heating of solar coronal plasma?'],
#  ['What are the key differences between laser propulsion and traditional chemical propulsion systems?'],
#  ['What is the divergence of the vector field \\( \\mathbf{F} = (xy^2, x^2z, yz^2) \\)?'],
#  ['What is the significance of the Riemann curvature tensor in the context of General Relativity?'],
#  ['What is a group homomorphism, and how does it relate to the concept of symmetry in mathematical structures?'],
#  ['What is the relationship between the residue theorem in complex analysis and the evaluation of real integrals using contour integration?'],
#  ['What are the key differences between explicit and implicit methods in solving ordinary differential equations numerically?'],
#  ['What are the key differences between conductors, semiconductors, and insulators in terms of their electronic band structures?'],
#  ['What are the key differences between quantum bits (qubits) and classical bits in terms of information representation?'],
#  ['What are the key differences between crystalline and amorphous materials?'],
#  ['What are the key principles of MRI technology and how do they relate to the physics of magnetic fields and radiofrequency pulses?'],
#  ['What are the key differences between LEDs and laser diodes in terms of their functionality and applications?'],
#  ['What are the main advantages and disadvantages of solar energy compared to wind energy?'],
#  ["How would you apply Newton's Second Law of Motion to differentiate between the effects of mass and acceleration on an object in a frictionless environment?"],
#  ['A 2 kg object is moving in a circular path of radius 3 m at a constant speed of 4 m/s. Calculate the net centripetal force acting on the object and determine the work done by this force over one complete revolution.'],
#  ['A 2 kg object is lifted vertically to a height of 5 meters. Calculate the work done against gravity and determine the power output if this lifting occurs over a time period of 4 seconds.'],
#  ['A 10 kg cart moving at 5 m/s collides elastically with a stationary 5 kg cart. What are the final velocities of both carts after the collision?'],
#  ['A solid disk of mass \\( M \\) and radius \\( R \\) is rotating about its central axis with an angular velocity \\( \\omega \\). A small mass \\( m \\) is dropped onto the edge of the disk and sticks to it. Assuming no external torques act on the system, what is the final angular velocity of the disk \\( \\omega_f \\) after the mass \\( m \\) adheres to the disk? Provide your answer in terms of \\( M \\), \\( R \\), \\( m \\), and \\( \\omega \\).'],
#  ['How does the concept of the Effective Potential Energy in orbital mechanics help explain the stability of orbits, and how is it mathematically derived from the gravitational potential and centrifugal forces?'],
#  ['How does the Navier-Stokes existence and smoothness problem relate to the behavior of incompressible fluid flow in three dimensions, and what implications does it have for predicting turbulence?'],
#  ['In a damped harmonic oscillator, how does the amplitude of oscillation change over time, and what factors influence the rate of this decay?'],
#  ['Consider a system described by a Lagrangian \\( L(q, \\dot{q}, t) = \\frac{1}{2} m \\dot{q}^2 - V(q) \\). Derive the Hamiltonian \\( H(q, p, t) \\) for this system and show how it relates to the original Lagrangian. Then, explain under what conditions the Hamiltonian can be interpreted as the total energy of the system.'],
#  ['How does the concept of specific heat capacity explain the differences in temperature changes between water and iron when equal amounts of heat energy are applied?'],
#  ['How does the concept of entropy challenge the idea of reversibility in thermodynamic processes, and can you provide an example of a real-world process that illustrates this principle?'],
#  ['How does the concept of entropy challenge the classical view of determinism in physical systems, and what implications does this have for our understanding of irreversible processes in thermodynamics?'],
#  ['In an irreversible adiabatic process, how does the change in entropy of the system compare to the change in entropy of the surroundings, and what implications does this have for the second law of thermodynamics?'],
#  ['Explain the implications of the second law of thermodynamics on the maximum efficiency of a heat engine and how this principle applies to the operation of a refrigerator.'],
#  ['How does the concept of ergodicity in statistical mechanics relate to the equivalence of microcanonical and canonical ensembles, and what implications does this have for the computation of macroscopic properties of a system?'],
#  ['How does the mean free path of gas molecules vary with changes in temperature and pressure, and what are the implications for gas viscosity in a confined space?'],
#  ['What is the significance of the concept of universal scaling behavior in phase transitions, and how does it relate to the renormalization group theory?'],
#  ['A point charge of magnitude \\( Q \\) is placed at the origin of a coordinate system. A second point charge of magnitude \\( -Q/2 \\) is placed at a distance \\( d \\) along the positive x-axis. Calculate the location along the x-axis where the net electric field due to both charges is zero.'],
#  ["In a complex AC circuit containing multiple components including resistors, capacitors, and inductors, how would you apply Kirchhoff's Voltage Law to find the total impedance of the circuit, and what role does the phase angle between voltage and current play in this analysis?"],
#  ["Consider a long, straight current-carrying wire with a uniform current \\(I\\) flowing through it. Using the Biot-Savart Law, derive the expression for the magnetic field \\(B\\) at a point located a distance \\(r\\) from the wire. Then, apply Ampère's Law to confirm that your result is consistent with the expression obtained using the Biot-Savart Law. What conditions must be satisfied for Ampère's Law to apply in this scenario?"],
#  ["How does Faraday's Law of Electromagnetic Induction quantitatively describe the relationship between the rate of change of magnetic flux and the induced electromotive force (EMF) in a closed loop, and how does Lenz’s Law provide the direction of the induced current in this scenario?"],
#  ["How do Maxwell's Equations illustrate the relationship between electromagnetic waves and their propagation speed in a vacuum, and how does this relate to the invariance of the speed of light in different inertial frames?"],
#  ['What are the implications of the wave-particle duality of light on the understanding of electromagnetic wave propagation in different media, particularly in the context of quantum mechanics?'],
#  ['What is the condition for constructive and destructive interference in a double-slit experiment, and how does this condition change if the light source is monochromatic versus polychromatic?'],
#  ['How does the concept of wave-particle duality challenge classical notions of objectivity in quantum mechanics, particularly in the context of measurement and observation?'],
#  ['How does the time-dependent Schrödinger equation relate to the concept of wave function collapse in quantum mechanics, and what implications does this have for the interpretation of quantum superposition?'],
#  ['What is the significance of the non-commutativity of quantum operators in relation to the uncertainty principle, and how does it manifest in the context of position and momentum operators?'],
#  ['What is the physical significance of the zero-point energy in the quantum harmonic oscillator, and how does it manifest in real-world systems?'],
#  ["How does the conservation of angular momentum apply to a system with both orbital and intrinsic (spin) angular momentum, particularly in the context of a particle's interaction in a magnetic field?"],
#  ['How does quantum tunneling facilitate the process of nuclear fusion in stars, and what implications does this have for our understanding of stellar evolution?'],
#  ['How does the Heisenberg Uncertainty Principle challenge the classical notion of determinism in physics, and what implications does this have for our understanding of the nature of reality at the quantum level?'],
#  ["How does the phenomenon of quantum entanglement challenge classical notions of locality and realism, particularly in the context of Bell's theorem and its implications for hidden variable theories?"],
#  ["What is the significance of the wavefunction's phase in quantum mechanics, and how does it relate to observable quantities such as probability densities and expectation values in the context of atomic and molecular systems?"],
#  ['How would you derive the time dilation formula from the Lorentz transformations, and what implications does this have for the concept of simultaneity in different inertial frames?'],
#  ['How do the dynamics of gravitational waves differ when propagating through a region of strong gravitational field, such as near a black hole, compared to a flat spacetime region?'],
#  ['If two observers are moving relative to each other at a velocity close to the speed of light, derive the expression for the time dilation experienced by one observer in terms of the proper time measured by the other observer. How does this relate to the invariance of the spacetime interval?'],
#  ['How does the relativistic expression for momentum differ from the classical expression, and what implications does this have for particle collisions at relativistic speeds?'],
#  ['What is the difference between alpha decay and beta decay in terms of the changes in atomic number and mass number of the nucleus, and how do these processes affect the stability of the resulting nuclides?'],
#  ['What are the key differences in the energy output and byproducts of deuterium-tritium fusion compared to proton-proton chain reactions in stars?'],
#  ['What are the fundamental principles behind the design and operation of a synchrotron, and how do they differ from those of a linear accelerator (linac)?'],
#  ['What are the implications of discovering a new fundamental particle that does not fit within the Standard Model of particle physics?'],
#  ['What is the significance of the Higgs boson in the context of electroweak symmetry breaking, and how does its mechanism contribute to the mass generation of other fundamental particles?'],
#  ['What is the significance of confinement in Quantum Chromodynamics, and how does it relate to the concept of asymptotic freedom?'],
#  ["How do Noether's Theorems relate to the symmetries of a physical system, and can you provide an example demonstrating the connection between a continuous symmetry and its corresponding conservation law?"],
#  ["In the context of crystallography, explain how the concept of symmetry operations applies to the classification of crystal systems and how these operations can lead to the determination of the crystal's space group."],
#  ['How does the concept of band structure explain the difference in electrical conductivity between conductors, semiconductors, and insulators, and what role do defects play in modifying these properties?'],
#  ['What are the key factors that influence the bandgap energy of semiconductors, and how do these factors affect the performance of electronic devices in varying temperature conditions?'],
#  ['What are the key differences between Type I and Type II superconductors in terms of their magnetic properties and critical fields?'],
#  ['What are the key differences in magnetic ordering and properties between ferromagnetic, ferrimagnetic, and antiferromagnetic materials, and how do these differences influence their practical applications in technology?'],
#  ['What is the significance of the order parameter in distinguishing between first-order and second-order phase transitions in ferromagnetic and antiferromagnetic materials, and how does it relate to symmetry breaking?'],
#  ['What are the potential environmental and health risks associated with the production, use, and disposal of nanomaterials, and how can these risks be effectively assessed and mitigated?'],
#  ['What are the main processes that govern the nucleosynthesis of elements during the various stages of stellar evolution, and how do these processes differ between low-mass and high-mass stars?'],
#  ['What evidence supports the existence of dark matter in galaxy rotation curves, and how do these observations challenge the predictions made by Newtonian physics?'],
#  ["What are the implications of the anisotropies observed in the Cosmic Microwave Background radiation for our understanding of the early universe's inflationary period?"],
#  ['How does the concept of dark energy challenge our understanding of gravity, and what implications does this have for the ultimate fate of the universe?'],
#  ['What are the primary differences in the formation mechanisms and end states of black holes and neutron stars, particularly in relation to the initial mass of the progenitor star?'],
#  ["What are the key atmospheric composition and pressure conditions required for liquid water to exist on a planet's surface, and how do these conditions influence the potential for habitability?"],
#  ['How does the phenomenon of gravitational lensing provide insights into the distribution of dark matter in the universe, and what are the implications of strong versus weak lensing in this context?'],
#  ['What are the key differences between thermal equilibrium and non-thermal equilibrium in plasma, and how do these conditions affect the behavior of charged particles within the plasma?'],
#  ['What are the primary challenges associated with achieving and maintaining the necessary plasma stability in magnetic confinement fusion reactors, and how do these challenges differ between tokamak and stellarator designs?'],
#  ['What are the implications of the magnetic Reynolds number on the stability of plasmas in astrophysical contexts, and how does it influence the transition between different MHD regimes?'],
#  ['What are the primary mechanisms that lead to the formation of cosmic ray acceleration in supernova remnants, and how do they explain the observed spectral index of these particles?'],
#  ['What are the key differences in energy efficiency and performance characteristics between laser propulsion systems utilizing photonic propulsion mechanisms and traditional chemical propulsion methods?'],
#  ['Consider a vector field \\(\\mathbf{F}(x, y, z) = (yz, xz, xy)\\). Calculate the divergence of \\(\\mathbf{F}\\), and then use the Divergence Theorem to evaluate the flux of \\(\\mathbf{F}\\) out of the surface of the cube defined by \\(0 \\leq x, y, z \\leq 1\\).'],
#  ['How does the Riemann curvature tensor relate to the geodesic deviation equation, and what physical significance does this relationship have in the context of General Relativity?'],
#  ['What is the significance of the Sylow theorems in determining the structure of finite groups, and can you provide an example of their application to a specific group?'],
#  ['Consider the function \\( f(z) = e^{iz} \\) defined on the complex plane. Using the residue theorem, evaluate the integral \\( \\int_{-\\infty}^{\\infty} e^{iz} \\, dz \\) and discuss the implications of this result for the Fourier transform of the function.'],
#  ['How would you implement a stable numerical method to solve the time-dependent Schrödinger equation for a one-dimensional potential well using finite difference techniques, and what specific challenges would you face regarding boundary conditions and stability?'],
#  ['What is the significance of the Fermi level in solid-state physics, and how does it influence the electrical properties of semiconductors and insulators?'],
#  ['What are the implications of the no-cloning theorem for the security of quantum key distribution protocols, and how does it relate to the concept of entanglement in ensuring information-theoretic security?'],
#  ['What are the key differences between thermoplastic and thermosetting polymers in terms of their molecular structure and mechanical properties?'],
#  ['How do the principles of thermodynamics apply to the understanding of protein folding and misfolding in the context of disease mechanisms?'],
#  ['How do the principles of quantum coherence and entanglement influence the performance of quantum dots in optoelectronic devices, and what implications does this have for the development of next-generation photonic circuits?'],
#  ['What are the key technical and economic challenges in scaling up the production and integration of green hydrogen into existing energy systems?'],
#  ["How would you apply Newton's Second Law to analyze the motion of a toy car launched down an inclined plane, considering factors such as friction, angle of incline, and mass?"],
#  ['A particle moves along a straight line such that its position as a function of time is given by \\( s(t) = 2t^3 - 12t^2 + 18t + 5 \\). Determine the times when the particle is at rest and calculate the acceleration of the particle at those times.'],
#  ['A block of mass 5 kg is initially at rest at the top of a frictionless incline of height 10 m. If the block slides down the incline, what will be its speed at the bottom of the incline? (Assume g = 9.81 m/s²)'],
#  ['A 2 kg object moving at 3 m/s collides elastically with a stationary 3 kg object. What are the final velocities of both objects after the collision?'],
#  ['A solid sphere of mass \\( m \\) and radius \\( r \\) rolls without slipping down an inclined plane that makes an angle \\( \\theta \\) with the horizontal. Calculate the angular momentum of the sphere about its center of mass when it reaches the bottom of the incline, given that it starts from rest and the height of the incline is \\( h \\).'],
#  ['What are the implications of the three-body problem on the stability of orbits in a system with a central mass and two orbiting bodies, and how does this affect long-term predictions of their trajectories?'],
#  ['How does the Navier-Stokes existence and smoothness problem relate to the behavior of solutions in three-dimensional incompressible fluid flow, and what implications does this have on turbulence modeling?'],
#  ['A mass-spring system undergoes simple harmonic motion with a spring constant \\( k \\) and a mass \\( m \\). If the amplitude of oscillation is doubled, how does the total mechanical energy of the system change, and what is the new expression for the total mechanical energy in terms of the spring constant and the new amplitude?'],
#  ["Consider a system described by a Lagrangian \\( L(q, \\dot{q}, t) = \\frac{1}{2}m\\dot{q}^2 - V(q) \\). Derive the Hamiltonian formulation for this system, and then demonstrate the conditions under which the Hamiltonian formulation conserves energy explicitly through the Hamilton's equations."],
#  ['What is the relationship between temperature and the kinetic energy of particles in a substance, and how does this relationship explain the difference in heat transfer mechanisms (conduction, convection, and radiation) among solids, liquids, and gases?'],
#  ['How does the Second Law of Thermodynamics apply to the concept of entropy in isolated systems, and what implications does this have for the direction of spontaneous processes?'],
#  ['How does the concept of microstates in statistical mechanics provide a deeper understanding of the Second Law of Thermodynamics, particularly in relation to the irreversibility of natural processes and the concept of entropy as a measure of disorder?'],
#  ['In an adiabatic process for an ideal gas, how does the change in internal energy relate to the work done on or by the gas, and what is the mathematical expression that describes this relationship?'],
#  ['What is the relationship between the efficiency of a heat engine and the coefficient of performance of a refrigerator when both operate between the same two thermal reservoirs?'],
#  ['Consider a system of N non-interacting particles in a one-dimensional box of length L. Each particle can occupy any quantum state specified by a wave function. Derive the expression for the canonical partition function \\( Z \\) of this system, and subsequently use it to obtain the Helmholtz free energy \\( F \\). How does the result change in the limit of high temperatures (classical limit)?'],
#  ['How does the Kinetic Theory of Gases derive the relationship between temperature and the average kinetic energy of gas molecules, and how would you apply it to explain real gas behavior under high pressure and low temperature conditions?'],
#  ['What is the significance of scaling relations in the context of renormalization group theory, and how do they apply to the behavior of physical quantities near a continuous phase transition?'],
#  ['A point charge of +3 µC is located at the origin, and a second point charge of -2 µC is located at (4, 0) meters. Calculate the electric field at the point (2, 0) meters due to both charges, and determine the net electric field direction at that point.'],
#  ["In a series circuit with a total resistance of 12 ohms and a current of 3 amps, what is the voltage across the entire circuit, and how would you apply Kirchhoff's Voltage Law if an additional resistor of 4 ohms is added in series?"],
#  ['Consider a long, straight current-carrying wire that generates a magnetic field around it. If you have two parallel wires carrying currents in the same direction, derive the expression for the force per unit length that one wire exerts on the other. Additionally, discuss how this force changes if the currents are in opposite directions.'],
#  ["A circular loop of wire with a radius of 0.1 m is placed in a uniform magnetic field that is decreasing at a rate of 0.05 T/s. Calculate the magnitude of the induced electromotive force (emf) in the loop and determine the direction of the induced current using Lenz's Law."],
#  ["How do Maxwell's Equations predict the existence of electromagnetic waves, and can you derive the wave equation from them?"],
#  ['What is the relationship between the wave vector and the electric and magnetic fields in a plane electromagnetic wave propagating in a vacuum, and how does this relate to the concept of polarization?'],
#  ['What is the minimum thickness of a thin film of oil (n = 1.5) on water (n = 1.33) that will cause destructive interference for light of wavelength 600 nm in air?'],
#  ['How does the concept of wave-particle duality challenge the classical distinctions between particles and waves, and what implications does this have for our understanding of quantum mechanics?'],
#  ['What are the implications of the time-dependent Schrödinger equation for a multi-particle system, and how does it lead to the concept of indistinguishability in quantum mechanics?'],
#  ['What is the significance of the spectral decomposition of an operator in quantum mechanics, and how can it be applied to analyze the dynamics of a quantum state represented as a linear combination of eigenstates?'],
#  ['Derive the time-independent Schrödinger equation for a one-dimensional quantum harmonic oscillator and solve for the energy eigenvalues and eigenfunctions, considering the effects of normalization.'],
#  ['How does the conservation of angular momentum apply to a quantum system with spin, and what role does it play in the context of quantum entanglement in multi-particle systems?'],
#  ['How does the phenomenon of quantum tunneling challenge classical notions of energy conservation, particularly in the context of particle interactions at subatomic scales?'],
#  ['How does the Heisenberg Uncertainty Principle fundamentally challenge the classical notion of determinism in quantum mechanics, and what implications does this have for the concept of particle trajectories?'],
#  ["How does the phenomenon of quantum entanglement challenge classical intuitions about locality and realism in the context of Bell's theorem experiments?"],
#  ['How do the quantum mechanical principles of superposition and entanglement explain the phenomenon of quantum tunneling in atomic scale processes?'],
#  ['How does the concept of simultaneity change for observers moving relative to each other, and what implications does this have for the measurement of time intervals between two events in different reference frames?'],
#  ['How do the polarization states of gravitational waves provide insight into the nature of the source that generated them, and what implications do these states have for our understanding of fundamental physics?'],
#  ['Derive the expression for the time dilation experienced by a moving observer in a frame moving at a velocity \\( v \\) relative to a stationary observer using the Lorentz transformation equations.'],
#  ['How does the relativistic momentum of a particle change as its velocity approaches the speed of light, and how does this lead to the concept of invariant mass versus relativistic mass?'],
#  ['What are the differences in decay mechanisms between alpha decay and beta decay, and how do these mechanisms affect the resultant daughter nuclides in terms of their stability and nuclear binding energy?'],
#  ['What are the specific conditions required to achieve and sustain nuclear fusion in a plasma state, and how do these conditions impact the choice of fusion fuel?'],
#  ['What are the key differences in detection mechanisms between a time projection chamber (TPC) and a liquid argon time projection chamber (LArTPC) in the context of neutrino physics experiments?'],
#  ['How do the properties of quarks, specifically their color charge and confinement, lead to the formation of hadrons, and what implications does this have for our understanding of the strong force?'],
#  ['How does the Higgs mechanism give mass to the W and Z bosons while leaving the photon massless in the context of the electroweak symmetry breaking?'],
#  ['What are the implications of asymptotic freedom in Quantum Chromodynamics for the behavior of quarks and gluons at high energies, and how does this property influence the confinement of color charge at low energies?'],
#  ["How does Noether's theorem connect the concept of symmetry in physical systems to the conservation laws observed in those systems, and can you provide an example illustrating this relationship?"],
#  ['What are the key differences in the coordination number and packing efficiency between face-centered cubic (FCC) and body-centered cubic (BCC) lattice structures?'],
#  ['Explain how the concept of wavefunctions in a periodic potential leads to the formation of energy bands and band gaps in solids, and discuss the implications for electrical conductivity in materials.'],
#  ['What are the primary mechanisms of charge carrier transport in semiconductor materials, and how do they influence the design of electronic devices such as MOSFETs and BJTs?'],
#  ['What are the mechanisms behind high-temperature superconductivity in cuprate materials, and how do they differ from conventional BCS theory?'],
#  ['What is the significance of the Curie temperature in ferromagnetic materials, and how does it affect their magnetic properties at different temperatures?'],
#  ['How does the two-dimensional Ising model exhibit a phase transition in the absence of an external magnetic field, and what role does the critical temperature play in distinguishing between ferromagnetic and paramagnetic phases?'],
#  ['What are the implications of quantum confinement effects in nanomaterials for electronic device performance, and how do these effects influence the design of next-generation semiconductor technologies?'],
#  ['What are the key differences in the fusion processes that occur in main sequence stars compared to those in red giant stars, and how do these differences affect their luminosity and lifecycle?'],
#  ['What evidence supports the hypothesis that dark matter comprises a significant portion of the mass within galaxy clusters, and how do observations of the Bullet Cluster serve to illustrate this relationship?'],
#  ['What is the significance of the anisotropies observed in the Cosmic Microwave Background radiation for our understanding of the early universe and the formation of large-scale structures?'],
#  ["How does the equation of state parameter \\( w \\) for dark energy affect the future dynamics of the universe's expansion, and what implications does this have for the ultimate fate of the universe?"],
#  ['What are the key differences in the formation processes and end states of black holes and neutron stars, particularly in relation to the core collapse of massive stars?'],
#  ['What are the key atmospheric compositions and conditions that differentiate a potentially habitable exoplanet from a non-habitable one, and how do these factors influence the stability of liquid water on its surface?'],
#  ['How does the gravitational lensing effect vary with the mass distribution of the lensing object and what are the implications for determining dark matter profiles in galaxies?'],
#  ['What are the key differences in the ionization processes between thermal and non-thermal plasmas, and how do these processes affect the properties and applications of each type?'],
#  ['What are the key differences in plasma confinement mechanisms between magnetic confinement fusion (MCF) and inertial confinement fusion (ICF), and how do these differences impact the efficiency and feasibility of achieving net energy gain in each approach?'],
#  ['How does the inclusion of plasma viscosity and Hall effect influence the stability of magnetic reconnection in astrophysical plasmas?'],
#  ['What are the primary mechanisms driving the acceleration of solar wind plasma, and how do these mechanisms relate to the properties of the solar corona?'],
#  ['What are the primary mechanisms of energy transfer in plasma-based propulsion systems, and how do they influence thrust performance and efficiency?'],
#  ['Prove that the divergence of the curl of any vector field \\( \\mathbf{F} \\) is zero, i.e., show that \\( \\nabla \\cdot (\\nabla \\times \\mathbf{F}) = 0 \\) for any differentiable vector field \\( \\mathbf{F} \\) in three-dimensional space.'],
#  ['What are the physical implications of the Riemann curvature tensor and how does it relate to the geodesic deviation equation in the context of General Relativity?'],
#  ['Prove or disprove that every non-abelian group must have a normal subgroup of index at most 2.'],
#  ['Prove that the Fourier transform of a tempered distribution, specifically the Heaviside step function, is given by \\( \\mathcal{F}\\{H(t)\\}(\\xi) = \\frac{1}{2} \\delta(\\xi) + \\frac{1}{i\\xi} \\).'],
#  ['How would you implement and optimize a parallel algorithm for solving the Navier-Stokes equations in turbulent flow, considering the challenges of stability and convergence in a time-dependent simulation?'],
#  ['What are the implications of the Kondo effect on the electrical resistivity of dilute magnetic alloys at low temperatures?'],
#  ['How does the concept of quantum entanglement challenge traditional notions of locality and realism in information theory, and what implications does this have for the development of quantum algorithms in comparison to classical ones?'],
#  ['What are the key mechanisms of fatigue failure in metallic materials, and how do microstructural features influence these mechanisms?'],
#  ['How do the principles of quantum mechanics apply to the mechanisms of drug-target interactions at the molecular level, and what implications does this have for the design of novel therapeutics?'],
#  ['What are the implications of the semiconductor bandgap engineering on the performance of quantum dot-based lasers in optoelectronic applications?'],
#  ['What are the key technological advancements in perovskite solar cells that address stability and scalability challenges compared to traditional silicon-based solar cells?']]
